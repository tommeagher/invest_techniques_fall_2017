# %%
#import your third-party libraries
import pandas as pd
import requests
import xmltodict #this one you may need to 'pip install xmltodict' 

#import the sleep function from the python standard library time module
from time import sleep

# %% [markdown]
# Here's the documentation from Amazon on the files and annual indexes it publishes: https://aws.amazon.com/public-datasets/irs-990/
# Note that they have indexes going back to 2011.

# %%
#read in your csv from the web with pandas' read_csv function
yearly_index = pd.read_csv('https://s3.amazonaws.com/irs-form-990/index_2016.csv')

# %%
#let's start exploring the resulting dataframe of data
#look at the column headings
yearly_index.columns
# Out:
# Index([u'RETURN_ID', u'FILING_TYPE', u'EIN', u'TAX_PERIOD', u'SUB_DATE',
#        u'TAXPAYER_NAME', u'RETURN_TYPE', u'DLN', u'OBJECT_ID'],
#       dtype='object')

# %%
#examine the first 5 rows
#remember the tab in Jupyter Notebooks will help autosuggest functions available for an object,
#in this case a pandas dataframe
yearly_index.head()
# Out:
#    RETURN_ID FILING_TYPE        EIN  TAX_PERIOD    SUB_DATE  \
# 0   13190365       EFILE  742661023      201412  02/09/2016
# 1   13189948       EFILE  562629114      201412  02/09/2016
# 2   13191270       EFILE  270678774      201509  02/09/2016
# 3   13191272       EFILE  464114252      201412  02/09/2016
# 4   13192838       EFILE  510311790      201506  02/10/2016
#
#                                        TAXPAYER_NAME RETURN_TYPE  \
# 0  HARRIET AND HARMON KELLEY FOUNDATION FOR THE ARTS       990PF
# 1            BROWN COMMUNITY DEVELOPMENT CORPORATION       990EZ
# 2         KIWANIS CLUB OF GLENDORA PROJECTS FUND INC       990EZ
# 3                                CONFETTI FOUNDATION       990EZ
# 4                                 SHEPHERD PLACE INC         990
#
#               DLN           OBJECT_ID
# 0  93491315003445  201543159349100344
# 1  93492310002195  201543109349200219
# 2  93492308002265  201513089349200226
# 3  93492308002365  201513089349200236
# 4  93493322003275  201523229349300327

# %%
#how many rows are in our dataframe?
yearly_index.count()
# Out:
# RETURN_ID        378420
# FILING_TYPE      378420
# EIN              378420
# TAX_PERIOD       378420
# SUB_DATE         378420
# TAXPAYER_NAME    378420
# RETURN_TYPE      378420
# DLN              378420
# OBJECT_ID        378420
# dtype: int64

# %%
#look at what's in the TAXPAYER_NAME column (or series in pandas)
yearly_index.TAXPAYER_NAME

#yearly_index['TAXPAYER_NAME'] would also work
# Out:
# 0         HARRIET AND HARMON KELLEY FOUNDATION FOR THE ARTS
# 1                   BROWN COMMUNITY DEVELOPMENT CORPORATION
# 2                KIWANIS CLUB OF GLENDORA PROJECTS FUND INC
# 3                                       CONFETTI FOUNDATION
# 4                                        SHEPHERD PLACE INC
# 5                        WISE VOLUNTEER FIRE DEPARTMENT INC
# 6                             A HOLE IN THE ROOF FOUNDATION
# 7         PTA DBA CARROLL ELEMENTARY PTA CALIFORNIA CONG...
# 8                LEAGUE OF THE SAN FRANCISCO CONSULAR CORPS
# 9              TAXICAB LIMOUSINE AND PARATRANSIT FOUNDATION
# 10                         WHATCOM COUNTY NORTH ROTARY CLUB
# 11          NEW HORIZON ACADEMY FOR EXCEPTIONAL STUDENTSINC
# 12                      FOUNDATION FOR CORPORATE TAX CREDIT
# 13                                       MYTEAM TRIUMPH INC
# 14                   SULGRAVE MANOR PRESERVATION FOUNDATION
# 15                   ROTARY CLUB OF LEESBURG FOUNDATION INC
# 16                                ABC WORKFORCE DEVELOPMENT
# 17        AMER DELEGATIONSACRED MILITARY CONSTANTINIAN O...
# 18                                      FALCON BOOSTER CLUB
# 19                            LABORATORY THEATER OF FLORIDA
# 20                              BEREA ROTARY FOUNDATION INC
# 21                       AMERICAN SAIL TRAINING ASSOCIATION
# 22                                   REFUGEE APOSTOLATE INC
# 23                                        RIVERCITY COMPANY
# 24        THOMAS JEFFERSON EMERGENCY MEDICAL SERVICES CO...
# 25                                        JOSHUA FOUNDATION
# 26                             KELLY S BRUSH FOUNDATION INC
# 27             INTERNATIONAL ASSOCIATION OF LIONS 290 CASEY
# 28                                     HAITI ENDOWMENT FUND
# 29                                 HIS CHASE FOUNDATION INC
#                                 ...
# 378390                               WORLD COMMUNITY IMPACT
# 378391                                      MISSION 292 INC
# 378392       EATON KNOLLS HOUSING DEVELOPMENT FUND CORP INC
# 378393                                FRED SANDBACK ARCHIVE
# 378394                    CASTRO VALLEY CHAMBER OF COMMERCE
# 378395                      OKLAHOMA EDUCATORS CREDIT UNION
# 378396                  NORTH EAST AREA CHAMBER OF COMMERCE
# 378397              SOUTHERN CALIFORNIA CHAPTER OF MSCI INC
# 378398                            JAMES F KEPPEL FOUNDATION
# 378399                 CLYDE AND SUMMER ANDERSON FOUNDATION
# 378400            EQUIPMENT AND ENGINE TRAINING COUNCIL INC
# 378401                 MCLAREN NORTHERN MICHIGAN FOUNDATION
# 378402                                    MEDERI FOUNDATION
# 378403                            CRANALEITH FOUNDATION INC
# 378404                              AREPA INC CO TONY HUANG
# 378405                                         CODE FOR FUN
# 378406                              MAPLE GROVE ARTS CENTER
# 378407                                  CARNEGIE CENTER INC
# 378408    SHAUGHNESSY FAMILY FOUNDATION CO JOSEPH F SHAU...
# 378409                       FRIENDS OF ST JOHNS CHAPEL INC
# 378410          UNITED WAY OF NORTH CENTRAL MISSISSIPPI INC
# 378411                   IMPERIAL BEACH CHAMBER OF COMMERCE
# 378412                   WASHINGTON GIRLS SELECT BASKETBALL
# 378413                           FRIENDS FOREVER FOUNDATION
# 378414                                FIRST TEE OF MERIDIAN
# 378415                              MACATAWA BAY YACHT CLUB
# 378416                             THOMPSON FALLS AMBULANCE
# 378417    MIDWEST AQUATIC PLANT MANAGEMENT SOCIETY INCOR...
# 378418                   ACADEMICSREVIEWORG CO BRUCE CHASSY
# 378419       SOUTH TOMS RIVER VOLUNTEER FIRST AID SQUAD INC
# Name: TAXPAYER_NAME, dtype: object

# %%
#what are the different categories of IRS Return Types that are available in the data?
#you'd have to check with the IRS to see what these different values really mean
#
#this returns an array, similar to a list in standard Python
yearly_index.RETURN_TYPE.unique()
# Out:
# array(['990PF', '990EZ', '990', '990O', '990EO'], dtype=object)

# %%
#let's count how many records there are for each type of return
#notice how we're chaining together several functions here
#start with your dataframe and group it by the RETURN_TYPE column
#then count it up and just show me one column of the resulting dataframe
yearly_index.groupby('RETURN_TYPE').count().RETURN_ID
# Out:
# RETURN_TYPE
# 990      160550
# 990EO     28537
# 990EZ     84652
# 990O      50987
# 990PF     53694
# Name: RETURN_ID, dtype: int64

# %%
#now let's filter our yearly_index dataframe to only show us rows that contain the word "MARSHALL"
#in the TAXPAYER_NAME column. Remember, this is case sensative
yearly_index[yearly_index.TAXPAYER_NAME.str.contains('MARSHALL')]
# Out:
#         RETURN_ID FILING_TYPE        EIN  TAX_PERIOD                SUB_DATE  \
# 3410     13181810       EFILE  630132555      201506              02/05/2016
# 3719     13090230       EFILE  550628843      201412              01/07/2016
# 5680     13094359       EFILE  541470430      201505              01/08/2016
# 6678     13099249       EFILE  521785229      201508              01/11/2016
# 7997     13099764       EFILE  464353634      201412              01/11/2016
# 8358     13096588       EFILE  272713485      201506              01/11/2016
# 9255     13102541       EFILE  363507987      201412              01/12/2016
# 9870     13104768       EFILE  621384200      201504              01/13/2016
# 11924    13106611       EFILE  631157063      201412              01/13/2016
# 14439    13111520       EFILE  440339110      201506              01/14/2016
# 14478    13112578       EFILE  330895024      201506              01/14/2016
# 16765    13116740       EFILE  240555024      201412              01/16/2016
# 18151    13116334       EFILE  270737687      201412              01/15/2016
# 18277    13115262       EFILE  421388168      201506              01/15/2016
# 18319    13116421       EFILE  300178911      201412              01/15/2016
# 20479    13122355       EFILE  237220922      201412              01/20/2016
# 20502    13122389       EFILE  561386785      201506              01/20/2016
# 22349    13126104       EFILE  546122969      201412              01/20/2016
# 22766    13125237       EFILE  380794015      201504              01/20/2016
# 23110    13125364       EFILE  726163215      201404              01/20/2016
# 23295    13125448       EFILE  311007800      201506              01/20/2016
# 24444    13130915       EFILE  746085768      201506              01/21/2016
# 27366    13131905       EFILE  410765672      201506              01/21/2016
# 28356    13131375       EFILE  237016022      201412              01/21/2016
# 29670    13135872       EFILE  610601267      201412              01/22/2016
# 33249    13139560       EFILE  760716481      201412              01/25/2016
# 33684    13142167       EFILE  203181488      201412              01/26/2016
# 34311    13147633       EFILE   43753636      201506              01/26/2016
# 35209    13145980       EFILE  431207213      201506              01/26/2016
# 38005    13149029       EFILE  420925825      201412              01/27/2016
# ...           ...         ...        ...         ...                     ...
# 350889   14019773       EFILE  431893211      201512   12/21/2016 7:59:15 AM
# 351053   14044409       EFILE  420984749      201509   12/30/2016 7:31:43 AM
# 351513   14041700       EFILE  237311600      201512   12/29/2016 2:03:42 PM
# 353465   14019461       EFILE  631180278      201512   12/21/2016 7:24:12 AM
# 353768   14005602       EFILE  351935467      201512   12/15/2016 5:46:20 PM
# 354352   14024058       EFILE  421333072      201512  12/21/2016 10:18:28 PM
# 355047   14023131       EFILE  351582974      201512   12/21/2016 6:36:45 PM
# 355836   14020587       EFILE  352416698      201512   12/21/2016 9:59:01 AM
# 356204   14021460       EFILE  880397249      201512  12/21/2016 11:32:09 AM
# 356742   14024117       EFILE  330895024      201606  12/21/2016 10:40:44 PM
# 357039   14022651       EFILE  455365095      201512   12/21/2016 5:36:43 PM
# 357066   14022190       EFILE  631103803      201509   12/21/2016 4:50:39 PM
# 357194   14019849       EFILE  351539175      201512   12/21/2016 8:00:51 AM
# 357277   14021815       EFILE  203708101      201512  12/21/2016 12:28:23 PM
# 358822   14036575       EFILE  264599924      201512   12/28/2016 1:33:26 PM
# 359619   14025794       EFILE  631230924      201509  12/22/2016 11:53:48 AM
# 362811   14027233       EFILE  611094309      201603   12/22/2016 6:00:23 PM
# 365626   14020327       EFILE  580662404      201512   12/21/2016 9:19:39 AM
# 367213   14033451       EFILE  232706791      201512  12/27/2016 11:26:16 PM
# 367570   14018463       EFILE  331122321      201512   12/20/2016 8:02:22 PM
# 367725   14000592       EFILE  472049160      201512   12/14/2016 4:32:10 PM
# 368208   14030783       EFILE  133157280      201512   12/23/2016 8:43:34 PM
# 371086   14028758       EFILE  611111663      201512  12/22/2016 10:46:12 PM
# 371970   14030663       EFILE  421469271      201512   12/23/2016 8:31:13 PM
# 372291   14016986       EFILE  420871626      201603   12/20/2016 4:24:42 PM
# 372305   14037083       EFILE  237447585      201512   12/28/2016 4:51:00 PM
# 373063   14019185       EFILE  420925825      201512   12/21/2016 6:10:56 AM
# 374281   14038157       EFILE  396043185      201512   12/28/2016 9:32:28 PM
# 374970   14031596       EFILE  232255636      201512  12/27/2016 11:47:48 AM
# 375322   14017324       EFILE  113585691      201512   12/20/2016 5:35:26 PM
#
#                                             TAXPAYER_NAME RETURN_TYPE  \
# 3410                 MARSHALL-DEKALB ELECTRIC COOPERATIVE        990O
# 3719                 MARSHALL COUNTY ANIMAL RESCUE LEAGUE         990
# 5680    GEORGE C MARSHALL BAND PARENTS ORGANIZATION OF...       990EZ
# 6678       THURGOOD MARSHALL CHILD DEVELOPMENT CENTER INC         990
# 7997                                 MARSHALL PROJECT INC         990
# 8358                                      MARSHALL M CLUB         990
# 9255             MARSHALL J AND JOYCE E PERSKY FOUNDATION       990PF
# 9870                    HUMANE SOCIETY OF MARSHALL CO INC         990
# 11924                      MARSHALL COUNTY HOME PLACE INC         990
# 14439                        MARSHALL CHAMBER OF COMMERCE        990O
# 14478               THURGOOD MARSHALL PARENT-TEACHER CLUB       990EZ
# 16765   AMERICAN LEGION WM MARSHALL CRAWFORD POST 131 INC        990O
# 18151          MARSHALL PLAN CHARITIES OF AFGHANISTAN INC         990
# 18277                        ILQ INC MARSHALL CMI HOUSING         990
# 18319   MARSHALL COUNTY COALITION AGAINST DOMESTIC VIO...         990
# 20479                   UNITED WAY OF MARSHALL COUNTY INC         990
# 20502                    MARSHALLBERG VOLUNTARY FIRE DEPT         990
# 22349   JOHN MARSHALL LODGE NO 2 FRATERNAL ORDER OF PO...       990EO
# 22766             LOYAL ORDER OF MOOSE MARSHALL LODGE 676        990O
# 23110   MARSHALL HERITAGE FOUNDATION FORMERLY MARSHALL...       990PF
# 23295                 EAST MARSHALL FIRE PROTECTION DISTR        990O
# 24444                          PTA MARSHALL MIDDLE SCHOOL       990EZ
# 27366                                     MARSHALL SCHOOL         990
# 28356        MARSHALL COUNTY FOUNDATION FOR FINE ARTS INC       990PF
# 29670                   MARSHALL COUNTY HOSPITAL DISTRICT         990
# 33249   JOHN W MARSHALL AND JERRY E MARSHALL FOUNDATIO...       990PF
# 33684              ALZHEIMERS SERVICES OF MARSHALL COUNTY         990
# 34311                                   MARSHALL ROAD INC         990
# 35209                   MARSHALL AREA SENIOR CITIZENS INC       990EZ
# 38005   MARSHALLTOWN CENTRAL BUSINESS DISTRICT MAIN ST...       990EO
# ...                                                   ...         ...
# 350889      MARSHALL NICHOLAS BEAZLEY AVIATION MUSEUM INC         990
# 351053            MARSHALL COUNTY CHILD CARE SERVICES INC         990
# 351513                   MARSHALL COUNTY QUARTERBACK CLUB       990EO
# 353465                MARSHALL COUNTY CHRISTMAS COALITION         990
# 353768                   MARSHALL COUNTY SHERRIFS RESERVE       990EZ
# 354352                      MARSHALLTOWN AREA SOCCER CLUB       990EZ
# 355047                    MARSHALL COUNTY MEMBERSHIP CORP        990O
# 355836              ARKANSAS COALITION OF MARSHALLESE INC       990EZ
# 356204         MARSHALL AND ELAINE SIEGEL FAMILY FOUNDATI       990PF
# 356742              THURGOOD MARSHALL PARENT-TEACHER CLUB       990EZ
# 357039          HOSPICE OF MARSHALL COUNTY FOUNDATION INC         990
# 357066  MARSHALL COUNTY COMMUNITY PUNISHMENT AND CORRE...         990
# 357194               MARSHALL COUNTY NEIGHBORHOOD COUNCIL         990
# 357277        MARSHALL AND ELLEN PETERS FAMILY FOUNDATION       990PF
# 358822                    MARSHALL CO HORSEMANS ASSOC INC       990EO
# 359619        MARSHALL COUNTY COURT REFERRAL SERVICES INC         990
# 362811             MARSHALL COUNTY ELKS LODGE INC NO 2707        990O
# 365626                       MARSHALLVILLE FOUNDATION INC       990PF
# 367213                       MARSHALLS CREEK FIRE COMPANY         990
# 367570                             MARSHALL HOME FUND INC       990PF
# 367725  MARSHALL B AND BRENDA J BROWN CHARITABLE FOUND...       990PF
# 368208  MARSHALL FAMILY FOUNDATION INC CO COOPERSMITH ...       990PF
# 371086                   MARSHALL CO HOME FOR EXCEPTIONAL         990
# 371970  FRIENDS OF THE MARSHALLTOWN IOWA PUBLIC LIBRAR...         990
# 372291                       MARSHALLTOWN AREA UNITED WAY         990
# 372305                       MARSHALLTOWN FOOTBALL LEAGUE       990EZ
# 373063  MARSHALLTOWN CENTRAL BUSINESS DISTRICT MAIN ST...       990EO
# 374281                 MARSHALL AND ILSLEY FOUNDATION INC       990PF
# 374970               MARSHALLS CREEK FIREMENS RELIEF ASSN         990
# 375322                     AMY MARSHALL DANCE COMPANY INC       990EZ
#
#                    DLN           OBJECT_ID
# 3410    93493314017495  201543149349301749
# 3719    93493260000035  201532609349300003
# 5680    93492254003145  201542549349200314
# 6678    93493302009225  201523029349300922
# 7997    93493275004115  201512759349300411
# 8358    93493300000335  201533009349300033
# 9255    93491255002005  201502559349100200
# 9870    93493257013175  201522579349301317
# 11924   93493258007305  201502589349300730
# 14439   93493301010585  201533019349301058
# 14478   93492287001005  201502879349200100
# 16765   93493259002075  201522599349300207
# 18151   93493288017175  201522889349301717
# 18277   93493317003455  201503179349300345
# 18319   93493288009085  201532889349300908
# 20479   93493320126155  201503209349312615
# 20502   93493320088015  201513209349308801
# 22349   93492288005085  201532889349200508
# 22766   93493287016695  201542879349301669
# 23110   93491299002635  201532999349100263
# 23295   93493324005115  201513249349300511
# 24444   93492320055455  201503209349205545
# 27366   93493298001515  201512989349300151
# 28356   93491288002055  201502889349100205
# 29670   93493320052725  201523209349305272
# 33249   93491320026775  201523209349102677
# 33684   93493317061675  201523179349306167
# 34311   93493317035525  201523179349303552
# 35209   93492260004215  201512609349200421
# 38005   93492258005315  201512589349200531
# ...                ...                 ...
# 350889  93493227001156  201602279349300115
# 351053  93493228054786  201632289349305478
# 351513  93492228046646  201642289349204664
# 353465  93493228034056  201602289349303405
# 353768  93492223003466  201612239349200346
# 354352  93492225012166  201612259349201216
# 355047  93493228074256  201602289349307425
# 355836  93492228046206  201602289349204620
# 356204  93491226000006  201602269349100000
# 356742  93492226000006  201602269349200000
# 357039  93493228019956  201602289349301995
# 357066  93493228025406  201602289349302540
# 357194  93493229001256  201602299349300125
# 357277  93491228009256  201602289349100925
# 358822  93492134005296  201641349349200529
# 359619  93493225022266  201612259349302226
# 362811  93493225039866  201612259349303986
# 365626  93491225001156  201602259349100115
# 367213  93493134015246  201641349349301524
# 367570  93491225012056  201602259349101205
# 367725  93491204006036  201632049349100603
# 368208  93491137018276  201621379349101827
# 371086  93493137018186  201631379349301818
# 371970  93493225009886  201632259349300988
# 372291  93493222007096  201642229349300709
# 372305  93492134038196  201641349349203819
# 373063  93492225016856  201602259349201685
# 374281  93491134011746  201641349349101174
# 374970  93493134015676  201621349349301567
# 375322  93492221007046  201642219349200704
#
# [273 rows x 9 columns]

# %%
#make a new dataframe with the result of our 'MARSHALL' filter
marshalls = yearly_index[yearly_index.TAXPAYER_NAME.str.contains('MARSHALL')]

# %%
#Let's filter our dataframe again to show us only the rows
#where the 990 form was the return using the == comparison operator
#count the rows in the new marshalls990 dataframe we've created
marshalls990 = marshalls[marshalls.RETURN_TYPE=="990"]

marshalls990.count()
# Out:
# RETURN_ID        127
# FILING_TYPE      127
# EIN              127
# TAX_PERIOD       127
# SUB_DATE         127
# TAXPAYER_NAME    127
# RETURN_TYPE      127
# DLN              127
# OBJECT_ID        127
# dtype: int64

# %%
#notice what's in the OBJECT_ID column of the marshalls990 dataframe
#these are unique IDs for each return, an essential component of the URL for the raw return data
marshalls990.OBJECT_ID
# Out:
# 3719      201532609349300003
# 6678      201523029349300922
# 7997      201512759349300411
# 8358      201533009349300033
# 9870      201522579349301317
# 11924     201502589349300730
# 18151     201522889349301717
# 18277     201503179349300345
# 18319     201532889349300908
# 20479     201503209349312615
# 20502     201513209349308801
# 27366     201512989349300151
# 29670     201523209349305272
# 33684     201523179349306167
# 34311     201523179349303552
# 48034     201503159349300310
# 48272     201523159349300317
# 53955     201543209349306229
# 55354     201543179349309384
# 61934     201513079349300201
# 67168     201543139349302334
# 70323     201533439349300443
# 74366     201523359349301112
# 76881     201513489349301201
# 79153     201533499349301153
# 79658     201523209349303737
# 82146     201523159349304167
# 87095     201513209349303386
# 87564     201533149349303648
# 89523     201543029349301714
#                  ...
# 296639    201621949349300017
# 298699    201611969349301606
# 302415    201601969349300135
# 303380    201621889349300242
# 305301    201611799349300901
# 309626    201601889349300820
# 312171    201641379349306444
# 319504    201601759349300805
# 320308    201612289349306666
# 323530    201622219349300627
# 326510    201602159349300300
# 327349    201612079349300021
# 333832    201642169349301189
# 337460    201602029349301350
# 338229    201631969349301623
# 339202    201612249349301206
# 344761    201642519349300324
# 346094    201632089349300123
# 350889    201602279349300115
# 351053    201632289349305478
# 353465    201602289349303405
# 357039    201602289349301995
# 357066    201602289349302540
# 357194    201602299349300125
# 359619    201612259349302226
# 367213    201641349349301524
# 371086    201631379349301818
# 371970    201632259349300988
# 372291    201642229349300709
# 374970    201621349349301567
# Name: OBJECT_ID, dtype: int64

# %%
#let's create a url to request the 990 data for The Marshall Project
#we could just create it like this:
#my_url = "https://s3.amazonaws.com/irs-form-990/201512759349300411_public.xml"
#but then we'd have to manually copy and paste a different one every time we want to see
#data for another nonprofit. 
#this way, we can just change the return_object_id variable and assign a new unique ID to it

return_object_id = "201512759349300411"
url_base = "https://s3.amazonaws.com/irs-form-990/"
#the "{0}".format(variable) is called string formatting. 
#the notation says "where you find the {x}, substitute in the string
#in the xth item in the format function arguments and create a new string
my_url = url_base+"{0}_public.xml".format(return_object_id)

# %%
#there's a lot happening here
#but this is a way to automatically (and quickly) run through every row in our dataframe
#and substitute the object_id value into a url string
#then assign it to a new column we're creating here called "url"

marshalls990['url'] = marshalls990.OBJECT_ID.apply(lambda x: url_base+"{0}_public.xml".format(x))

#if you see a scary looking red block below this, don't worry. it's a warning but not an error
# Out:
# /Users/tommeagher/.virtualenvs/pandas/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#though they're truncated in our display here, we've now created the url for each dataset
#on Amazon relating to the nonprofits in our dataframe
marshalls990['url']
# Out:
# 3719      https://s3.amazonaws.com/irs-form-990/20153260...
# 6678      https://s3.amazonaws.com/irs-form-990/20152302...
# 7997      https://s3.amazonaws.com/irs-form-990/20151275...
# 8358      https://s3.amazonaws.com/irs-form-990/20153300...
# 9870      https://s3.amazonaws.com/irs-form-990/20152257...
# 11924     https://s3.amazonaws.com/irs-form-990/20150258...
# 18151     https://s3.amazonaws.com/irs-form-990/20152288...
# 18277     https://s3.amazonaws.com/irs-form-990/20150317...
# 18319     https://s3.amazonaws.com/irs-form-990/20153288...
# 20479     https://s3.amazonaws.com/irs-form-990/20150320...
# 20502     https://s3.amazonaws.com/irs-form-990/20151320...
# 27366     https://s3.amazonaws.com/irs-form-990/20151298...
# 29670     https://s3.amazonaws.com/irs-form-990/20152320...
# 33684     https://s3.amazonaws.com/irs-form-990/20152317...
# 34311     https://s3.amazonaws.com/irs-form-990/20152317...
# 48034     https://s3.amazonaws.com/irs-form-990/20150315...
# 48272     https://s3.amazonaws.com/irs-form-990/20152315...
# 53955     https://s3.amazonaws.com/irs-form-990/20154320...
# 55354     https://s3.amazonaws.com/irs-form-990/20154317...
# 61934     https://s3.amazonaws.com/irs-form-990/20151307...
# 67168     https://s3.amazonaws.com/irs-form-990/20154313...
# 70323     https://s3.amazonaws.com/irs-form-990/20153343...
# 74366     https://s3.amazonaws.com/irs-form-990/20152335...
# 76881     https://s3.amazonaws.com/irs-form-990/20151348...
# 79153     https://s3.amazonaws.com/irs-form-990/20153349...
# 79658     https://s3.amazonaws.com/irs-form-990/20152320...
# 82146     https://s3.amazonaws.com/irs-form-990/20152315...
# 87095     https://s3.amazonaws.com/irs-form-990/20151320...
# 87564     https://s3.amazonaws.com/irs-form-990/20153314...
# 89523     https://s3.amazonaws.com/irs-form-990/20154302...
#                                 ...
# 296639    https://s3.amazonaws.com/irs-form-990/20162194...
# 298699    https://s3.amazonaws.com/irs-form-990/20161196...
# 302415    https://s3.amazonaws.com/irs-form-990/20160196...
# 303380    https://s3.amazonaws.com/irs-form-990/20162188...
# 305301    https://s3.amazonaws.com/irs-form-990/20161179...
# 309626    https://s3.amazonaws.com/irs-form-990/20160188...
# 312171    https://s3.amazonaws.com/irs-form-990/20164137...
# 319504    https://s3.amazonaws.com/irs-form-990/20160175...
# 320308    https://s3.amazonaws.com/irs-form-990/20161228...
# 323530    https://s3.amazonaws.com/irs-form-990/20162221...
# 326510    https://s3.amazonaws.com/irs-form-990/20160215...
# 327349    https://s3.amazonaws.com/irs-form-990/20161207...
# 333832    https://s3.amazonaws.com/irs-form-990/20164216...
# 337460    https://s3.amazonaws.com/irs-form-990/20160202...
# 338229    https://s3.amazonaws.com/irs-form-990/20163196...
# 339202    https://s3.amazonaws.com/irs-form-990/20161224...
# 344761    https://s3.amazonaws.com/irs-form-990/20164251...
# 346094    https://s3.amazonaws.com/irs-form-990/20163208...
# 350889    https://s3.amazonaws.com/irs-form-990/20160227...
# 351053    https://s3.amazonaws.com/irs-form-990/20163228...
# 353465    https://s3.amazonaws.com/irs-form-990/20160228...
# 357039    https://s3.amazonaws.com/irs-form-990/20160228...
# 357066    https://s3.amazonaws.com/irs-form-990/20160228...
# 357194    https://s3.amazonaws.com/irs-form-990/20160229...
# 359619    https://s3.amazonaws.com/irs-form-990/20161225...
# 367213    https://s3.amazonaws.com/irs-form-990/20164134...
# 371086    https://s3.amazonaws.com/irs-form-990/20163137...
# 371970    https://s3.amazonaws.com/irs-form-990/20163225...
# 372291    https://s3.amazonaws.com/irs-form-990/20164222...
# 374970    https://s3.amazonaws.com/irs-form-990/20162134...
# Name: url, dtype: object

# %%
#here we use the get function of the requests library to perform 
#a "get" request from the web for the url we created.
#then we pull out the text attribute of the resulting requests response object
#the [3:] means "grab everything in my string starting at the 4th character (remember we
#start counting at 0 in python) until then end. 
#that chops off some nasty unicode formatting that otherwise screws up our parser
#then we decode the utf-8 (unicode) that comes back to handle any weird
xml_return = requests.get(my_url).text[3:].decode('utf-8')

#this gives us an xml file, which is a text format for data. Rather than the PDF image
#of 990s we see when we search GuideStar or Nonprofit Explorer, we get the underlying data
#which we can store and analyze

# %%
#now, we're finally using that xmltodict library we installed earlier
#it's parse function takes the string of the xml data and converts it into 
#a nested dict (actually and OrderedDict). This will be much easier to use in Python
#than xml, trust me.
xmltodict.parse(xml_return)
# Out:
# OrderedDict([(u'Return',
#               OrderedDict([(u'@xmlns', u'http://www.irs.gov/efile'),
#                            (u'@xmlns:xsi',
#                             u'http://www.w3.org/2001/XMLSchema-instance'),
#                            (u'@xsi:schemaLocation',
#                             u'http://www.irs.gov/efile'),
#                            (u'@returnVersion', u'2014v5.0'),
#                            (u'ReturnHeader',
#                             OrderedDict([(u'@binaryAttachmentCnt', u'0'),
#                                          (u'ReturnTs',
#                                           u'2015-10-02T10:09:50-05:00'),
#                                          (u'TaxPeriodEndDt', u'2014-12-31'),
#                                          (u'PreparerFirmGrp',
#                                           OrderedDict([(u'PreparerFirmEIN',
#                                                         u'131655065'),
#                                                        (u'PreparerFirmName',
#                                                         OrderedDict([(u'BusinessNameLine1Txt',
#                                                                       u'LUTZ AND CARR CPAS LLP')])),
#                                                        (u'PreparerUSAddress',
#                                                         OrderedDict([(u'AddressLine1Txt',
#                                                                       u'300 EAST 42ND STREET'),
#                                                                      (u'CityNm',
#                                                                       u'NEW YORK'),
#                                                                      (u'StateAbbreviationCd',
#                                                                       u'NY'),
#                                                                      (u'ZIPCd',
#                                                                       u'10017')]))])),
#                                          (u'ReturnTypeCd', u'990'),
#                                          (u'TaxPeriodBeginDt', u'2014-01-01'),
#                                          (u'Filer',
#                                           OrderedDict([(u'EIN', u'464353634'),
#                                                        (u'BusinessName',
#                                                         OrderedDict([(u'BusinessNameLine1Txt',
#                                                                       u'THE MARSHALL PROJECT INC')])),
#                                                        (u'BusinessNameControlTxt',
#                                                         u'MARS'),
#                                                        (u'PhoneNum',
#                                                         u'2128035200'),
#                                                        (u'USAddress',
#                                                         OrderedDict([(u'AddressLine1Txt',
#                                                                       u'156 WEST 56TH STREET NO 701'),
#                                                                      (u'CityNm',
#                                                                       u'NEW YORK'),
#                                                                      (u'StateAbbreviationCd',
#                                                                       u'NY'),
#                                                                      (u'ZIPCd',
#                                                                       u'10019')]))])),
#                                          (u'BusinessOfficerGrp',
#                                           OrderedDict([(u'PersonNm',
#                                                         u'ELCHONON STERN'),
#                                                        (u'PersonTitleTxt',
#                                                         u'SECRETARY/TREASURER, CFO'),
#                                                        (u'PhoneNum',
#                                                         u'2128035200'),
#                                                        (u'SignatureDt',
#                                                         u'2015-09-28'),
#                                                        (u'DiscussWithPaidPreparerInd',
#                                                         u'1')])),
#                                          (u'PreparerPersonGrp',
#                                           OrderedDict([(u'PreparerPersonNm',
#                                                         u'FREDERICK MARTENS'),
#                                                        (u'PTIN', u'P00298107'),
#                                                        (u'PhoneNum',
#                                                         u'2126972299')])),
#                                          (u'TaxYr', u'2014'),
#                                          (u'BuildTS',
#                                           u'2016-02-25 16:41:14Z')])),
#                            (u'ReturnData',
#                             OrderedDict([(u'@documentCnt', u'8'),
#                                          (u'IRS990',
#                                           OrderedDict([(u'@documentId',
#                                                         u'RetDoc1038000001'),
#                                                        (u'@referenceDocumentId',
#                                                         u'RetDoc1044400001'),
#                                                        (u'AddressChangeInd',
#                                                         u'X'),
#                                                        (u'InitialReturnInd',
#                                                         u'X'),
#                                                        (u'DoingBusinessAsName',
#                                                         OrderedDict([(u'BusinessNameLine1Txt',
#                                                                       u'THE MARSHALL PROJECT INC')])),
#                                                        (u'PrincipalOfficerNm',
#                                                         u'NEIL BARSKY'),
#                                                        (u'USAddress',
#                                                         OrderedDict([(u'AddressLine1Txt',
#                                                                       u'156 WEST 56TH STREET NO 701'),
#                                                                      (u'CityNm',
#                                                                       u'NEW YORK'),
#                                                                      (u'StateAbbreviationCd',
#                                                                       u'NY'),
#                                                                      (u'ZIPCd',
#                                                                       u'10019')])),
#                                                        (u'GrossReceiptsAmt',
#                                                         u'5139255'),
#                                                        (u'GroupReturnForAffiliatesInd',
#                                                         u'0'),
#                                                        (u'Organization501c3Ind',
#                                                         u'X'),
#                                                        (u'WebsiteAddressTxt',
#                                                         u'WWW.THEMARSHALLPROJECT.ORG'),
#                                                        (u'TypeOfOrganizationCorpInd',
#                                                         u'X'),
#                                                        (u'FormationYr',
#                                                         u'2014'),
#                                                        (u'LegalDomicileStateCd',
#                                                         u'DE'),
#                                                        (u'ActivityOrMissionDesc',
#                                                         u'THE MARSHALL PROJECT IS A NONPROFIT, NONPARTISAN NEWS ORGANIZATION COVERING CRIMINAL JUSTICE.'),
#                                                        (u'VotingMembersGoverningBodyCnt',
#                                                         u'10'),
#                                                        (u'VotingMembersIndependentCnt',
#                                                         u'9'),
#                                                        (u'TotalEmployeeCnt',
#                                                         u'28'),
#                                                        (u'TotalVolunteersCnt',
#                                                         u'9'),
#                                                        (u'TotalGrossUBIAmt',
#                                                         u'0'),
#                                                        (u'NetUnrelatedBusTxblIncmAmt',
#                                                         u'0'),
#                                                        (u'CYContributionsGrantsAmt',
#                                                         u'5139255'),
#                                                        (u'CYProgramServiceRevenueAmt',
#                                                         u'0'),
#                                                        (u'CYInvestmentIncomeAmt',
#                                                         u'0'),
#                                                        (u'CYOtherRevenueAmt',
#                                                         u'0'),
#                                                        (u'CYTotalRevenueAmt',
#                                                         u'5139255'),
#                                                        (u'CYGrantsAndSimilarPaidAmt',
#                                                         u'0'),
#                                                        (u'CYBenefitsPaidToMembersAmt',
#                                                         u'0'),
#                                                        (u'CYSalariesCompEmpBnftPaidAmt',
#                                                         u'1854290'),
#                                                        (u'CYTotalProfFndrsngExpnsAmt',
#                                                         u'0'),
#                                                        (u'CYTotalFundraisingExpenseAmt',
#                                                         u'175454'),
#                                                        (u'CYOtherExpensesAmt',
#                                                         u'587474'),
#                                                        (u'CYTotalExpensesAmt',
#                                                         u'2441764'),
#                                                        (u'CYRevenuesLessExpensesAmt',
#                                                         u'2697491'),
#                                                        (u'TotalAssetsEOYAmt',
#                                                         u'2728362'),
#                                                        (u'TotalLiabilitiesEOYAmt',
#                                                         u'30871'),
#                                                        (u'NetAssetsOrFundBalancesEOYAmt',
#                                                         u'2697491'),
#                                                        (u'MissionDesc',
#                                                         u'THE MARSHALL PROJECT IS A NONPROFIT, NONPARTISAN NEWS ORGANIZATION COVERING CRIMINAL JUSTICE.'),
#                                                        (u'SignificantNewProgramSrvcInd',
#                                                         u'0'),
#                                                        (u'SignificantChangeInd',
#                                                         u'0'),
#                                                        (u'ExpenseAmt',
#                                                         u'1878549'),
#                                                        (u'Desc',
#                                                         u"MARSHALLPROJECT.ORG WEBSITETHE MARSHALL PROJECT WEBSITE SERVES AS A NON PARTISAN NEWS WEBSITE DEDICATED TO REPORTING ON AND ANALYZING AMERICA'S CRIMINAL JUSTICE SYSTEM IN AN EFFORT TO EDUCATE THE PUBLIC AND LAUNCH A NATIONAL DISCUSSION ON CRIMINAL JUSTICE WITH THE ULTIMATE GOAL OF IMPROVING THE US COURT AND PRISON SYSTEMS."),
#                                                        (u'TotalProgramServiceExpensesAmt',
#                                                         u'1878549'),
#                                                        (u'DescribedInSection501c3Ind',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1039100001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'ScheduleBRequiredInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1234500001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'PoliticalCampaignActyInd',
#                                                         u'0'),
#                                                        (u'LobbyingActivitiesInd',
#                                                         u'0'),
#                                                        (u'SubjectToProxyTaxInd',
#                                                         u'0'),
#                                                        (u'DonorAdvisedFundInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'ConservationEasementsInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'CollectionsOfArtInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'CreditCounselingInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'TempOrPermanentEndowmentsInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'ReportLandBuildingEquipmentInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'ReportInvestmentsOtherSecInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'ReportProgramRelatedInvstInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'ReportOtherAssetsInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'ReportOtherLiabilitiesInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'IncludeFIN48FootnoteInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'IndependentAuditFinclStmtInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'ConsolidatedAuditFinclStmtInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1040000001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'SchoolOperatingInd',
#                                                         u'0'),
#                                                        (u'ForeignOfficeInd',
#                                                         u'0'),
#                                                        (u'ForeignActivitiesInd',
#                                                         u'0'),
#                                                        (u'MoreThan5000KToOrgInd',
#                                                         u'0'),
#                                                        (u'MoreThan5000KToIndividualsInd',
#                                                         u'0'),
#                                                        (u'ProfessionalFundraisingInd',
#                                                         u'0'),
#                                                        (u'FundraisingActivitiesInd',
#                                                         u'0'),
#                                                        (u'GamingActivitiesInd',
#                                                         u'0'),
#                                                        (u'OperateHospitalInd',
#                                                         u'0'),
#                                                        (u'GrantsToOrganizationsInd',
#                                                         u'0'),
#                                                        (u'GrantsToIndividualsInd',
#                                                         u'0'),
#                                                        (u'ScheduleJRequiredInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042400001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'TaxExemptBondsInd',
#                                                         u'0'),
#                                                        (u'EngagedInExcessBenefitTransInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'PYExcessBenefitTransInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'LoanOutstandingInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'GrantToRelatedPersonInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'BusinessRlnWithOrgMemInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'BusinessRlnWithFamMemInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'BusinessRlnWithOfficerEntInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042800001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'DeductibleNonCashContriInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042900001'),
#                                                                      ('#text',
#                                                                       u'1')])),
#                                                        (u'DeductibleArtContributionInd',
#                                                         OrderedDict([(u'@referenceDocumentId',
#                                                                       u'RetDoc1042900001'),
#                                                                      ('#text',
#                                                                       u'0')])),
#                                                        (u'TerminateOperationsInd',
#                                                         u'0'),
#                                                        (u'PartialLiquidationInd',
#                                                         u'0'),
#                                                        (u'DisregardedEntityInd',
#                                                         u'0'),
#                                                        (u'RelatedEntityInd',
#                                                         u'0'),
#                                                        (u'RelatedOrganizationCtrlEntInd',
#                                                         u'0'),
#                                                        (u'TrnsfrExmptNonChrtblRltdOrgInd',
#                                                         u'0'),
#                                                        (u'ActivitiesConductedPrtshpInd',
#                                                         u'0'),
#                                                        (u'ScheduleORequiredInd',
#                                                         u'1'),
#                                                        (u'IRPDocumentCnt',
#                                                         u'10'),
#                                                        (u'IRPDocumentW2GCnt',
#                                                         u'0'),
#                                                        (u'EmployeeCnt', u'28'),
#                                                        (u'EmploymentTaxReturnsFiledInd',
#                                                         u'1'),
#                                                        (u'UnrelatedBusIncmOverLimitInd',
#                                                         u'0'),
#                                                        (u'ForeignFinancialAccountInd',
#                                                         u'0'),
#                                                        (u'ProhibitedTaxShelterTransInd',
#                                                         u'0'),
#                                                        (u'TaxablePartyNotificationInd',
#                                                         u'0'),
#                                                        (u'NondeductibleContributionsInd',
#                                                         u'0'),
#                                                        (u'QuidProQuoContributionsInd',
#                                                         u'0'),
#                                                        (u'Form8282PropertyDisposedOfInd',
#                                                         u'0'),
#                                                        (u'RcvFndsToPayPrsnlBnftCntrctInd',
#                                                         u'0'),
#                                                        (u'PayPremiumsPrsnlBnftCntrctInd',
#                                                         u'0'),
#                                                        (u'IndoorTanningServicesInd',
#                                                         u'0'),
#                                                        (u'InfoInScheduleOPartVIInd',
#                                                         u'X'),
#                                                        (u'GoverningBodyVotingMembersCnt',
#                                                         u'10'),
#                                                        (u'IndependentVotingMemberCnt',
#                                                         u'9'),
#                                                        (u'FamilyOrBusinessRlnInd',
#                                                         u'1'),
#                                                        (u'DelegationOfMgmtDutiesInd',
#                                                         u'0'),
#                                                        (u'ChangeToOrgDocumentsInd',
#                                                         u'0'),
#                                                        (u'MaterialDiversionOrMisuseInd',
#                                                         u'0'),
#                                                        (u'MembersOrStockholdersInd',
#                                                         u'0'),
#                                                        (u'ElectionOfBoardMembersInd',
#                                                         u'0'),
#                                                        (u'DecisionsSubjectToApprovaInd',
#                                                         u'0'),
#                                                        (u'MinutesOfGoverningBodyInd',
#                                                         u'1'),
#                                                        (u'MinutesOfCommitteesInd',
#                                                         u'1'),
#                                                        (u'OfficerMailingAddressInd',
#                                                         u'0'),
#                                                        (u'LocalChaptersInd',
#                                                         u'0'),
#                                                        (u'Form990ProvidedToGvrnBodyInd',
#                                                         u'1'),
#                                                        (u'ConflictOfInterestPolicyInd',
#                                                         u'1'),
#                                                        (u'AnnualDisclosureCoveredPrsnInd',
#                                                         u'1'),
#                                                        (u'RegularMonitoringEnfrcInd',
#                                                         u'1'),
#                                                        (u'WhistleblowerPolicyInd',
#                                                         u'1'),
#                                                        (u'DocumentRetentionPolicyInd',
#                                                         u'0'),
#                                                        (u'CompensationProcessCEOInd',
#                                                         u'1'),
#                                                        (u'CompensationProcessOtherInd',
#                                                         u'1'),
#                                                        (u'InvestmentInJointVentureInd',
#                                                         u'1'),
#                                                        (u'WrittenPolicyOrProcedureInd',
#                                                         u'1'),
#                                                        (u'StatesWhereCopyOfReturnIsFldCd',
#                                                         [u'NY', u'DE']),
#                                                        (u'UponRequestInd',
#                                                         u'X'),
#                                                        (u'BooksInCareOfDetail',
#                                                         OrderedDict([(u'BusinessName',
#                                                                       OrderedDict([(u'BusinessNameLine1Txt',
#                                                                                     u'ELCHONON STERN')])),
#                                                                      (u'PhoneNum',
#                                                                       u'2128035200'),
#                                                                      (u'USAddress',
#                                                                       OrderedDict([(u'AddressLine1Txt',
#                                                                                     u'156 WEST 56TH STREET'),
#                                                                                    (u'CityNm',
#                                                                                     u'NEW YORK'),
#                                                                                    (u'StateAbbreviationCd',
#                                                                                     u'NY'),
#                                                                                    (u'ZIPCd',
#                                                                                     u'10019')]))])),
#                                                        (u'Form990PartVIISectionAGrp',
#                                                         [OrderedDict([(u'PersonNm',
#                                                                        u'NEIL BARSKY'),
#                                                                       (u'TitleTxt',
#                                                                        u'CHAIR'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'30.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'OfficerInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'ELCHONON STERN'),
#                                                                       (u'TitleTxt',
#                                                                        u'SECRETARY/TREASURER, CFO'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'30.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'OfficerInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'70000'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'FRED CUMMINGS'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'NICHOLAS GOLDBERG'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'JEFFREY HALIS'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'BARI MATTES'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'WILLIAM L MCCOMB'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'JONATHAN MOSES'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'BEN REITER'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'DANA VINCENT'),
#                                                                       (u'TitleTxt',
#                                                                        u'BOARD MEMBER'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'1.00'),
#                                                                       (u'IndividualTrusteeOrDirectorInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
#                                                                        u'0'),
#                                                                       (u'ReportableCompFromRltdOrgAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'WILLIAM KELLER'),
#                                                                       (u'TitleTxt',
#                                                                        u'EDITOR-IN-CHIEF'),
#                                                                       (u'AverageHoursPerWeekRt',
#                                                                        u'40.00'),
#                                                                       (u'KeyEmployeeInd',
#                                                                        u'X'),
#                                                                       (u'ReportableCompFromOrgAmt',
# ...
#                                          (u'IRS990ScheduleJ',
#                                           OrderedDict([(u'@documentId',
#                                                         u'RetDoc1042400001'),
#                                                        (u'Form990OfOtherOrganizationsInd',
#                                                         u'X'),
#                                                        (u'BoardOrCommitteeApprovalInd',
#                                                         u'X'),
#                                                        (u'SeverancePaymentInd',
#                                                         u'0'),
#                                                        (u'SupplementalNonqualRtrPlanInd',
#                                                         u'0'),
#                                                        (u'EquityBasedCompArrngmInd',
#                                                         u'0'),
#                                                        (u'CompBasedOnRevenueOfFlngOrgInd',
#                                                         u'0'),
#                                                        (u'CompBsdOnRevRelatedOrgsInd',
#                                                         u'0'),
#                                                        (u'CompBsdNetEarnsFlngOrgInd',
#                                                         u'0'),
#                                                        (u'CompBsdNetEarnsRltdOrgsInd',
#                                                         u'0'),
#                                                        (u'AnyNonFixedPaymentsInd',
#                                                         u'0'),
#                                                        (u'InitialContractExceptionInd',
#                                                         u'0'),
#                                                        (u'RltdOrgOfficerTrstKeyEmplGrp',
#                                                         [OrderedDict([(u'PersonNm',
#                                                                        u'WILLIAM KELLER'),
#                                                                       (u'TitleTxt',
#                                                                        u'EDITOR-IN-CHIEF'),
#                                                                       (u'BaseCompensationFilingOrgAmt',
#                                                                        u'200000'),
#                                                                       (u'CompensationBasedOnRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'BonusFilingOrganizationAmount',
#                                                                        u'0'),
#                                                                       (u'BonusRelatedOrganizationsAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationFilingOrgAmt',
#                                                                        u'225'),
#                                                                       (u'OtherCompensationRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'DeferredCompensationFlngOrgAmt',
#                                                                        u'0'),
#                                                                       (u'DeferredCompRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'NontaxableBenefitsFilingOrgAmt',
#                                                                        u'25352'),
#                                                                       (u'NontaxableBenefitsRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'TotalCompensationFilingOrgAmt',
#                                                                        u'225577'),
#                                                                       (u'TotalCompensationRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'CompReportPrior990FilingOrgAmt',
#                                                                        u'0'),
#                                                                       (u'CompReportPrior990RltdOrgsAmt',
#                                                                        u'0')]),
#                                                          OrderedDict([(u'PersonNm',
#                                                                        u'TIM GOLDEN'),
#                                                                       (u'TitleTxt',
#                                                                        u'MANAGING EDITOR'),
#                                                                       (u'BaseCompensationFilingOrgAmt',
#                                                                        u'122005'),
#                                                                       (u'CompensationBasedOnRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'BonusFilingOrganizationAmount',
#                                                                        u'0'),
#                                                                       (u'BonusRelatedOrganizationsAmt',
#                                                                        u'0'),
#                                                                       (u'OtherCompensationFilingOrgAmt',
#                                                                        u'225'),
#                                                                       (u'OtherCompensationRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'DeferredCompensationFlngOrgAmt',
#                                                                        u'16667'),
#                                                                       (u'DeferredCompRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'NontaxableBenefitsFilingOrgAmt',
#                                                                        u'24746'),
#                                                                       (u'NontaxableBenefitsRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'TotalCompensationFilingOrgAmt',
#                                                                        u'163643'),
#                                                                       (u'TotalCompensationRltdOrgsAmt',
#                                                                        u'0'),
#                                                                       (u'CompReportPrior990FilingOrgAmt',
#                                                                        u'0'),
#                                                                       (u'CompReportPrior990RltdOrgsAmt',
#                                                                        u'0')])])])),
#                                          (u'IRS990ScheduleL',
#                                           OrderedDict([(u'@documentId',
#                                                         u'RetDoc1042800001'),
#                                                        (u'BusTrInvolveInterestedPrsnGrp',
#                                                         OrderedDict([(u'NameOfInterested',
#                                                                       OrderedDict([(u'BusinessName',
#                                                                                     OrderedDict([(u'BusinessNameLine1Txt',
#                                                                                                   u'BARSKY VENTURES')]))])),
#                                                                      (u'RelationshipDescriptionTxt',
#                                                                       u'COMPANY OWNED BY NEIL BARSKY, CHAIR'),
#                                                                      (u'TransactionAmt',
#                                                                       u'86129'),
#                                                                      (u'TransactionDesc',
#                                                                       u'THE ORGANIZATION REIMBURSES BARSKY VENTURES FOR ITS PRO RATA SHARE OF TOTAL OCCUPANCY COSTS, INCLUDING UTILITIES, PROPERTY TAXES, TELEPHONE AND INTERNET SERVICES, SHARED OFFICE EQUIPMENT AND MAINTENANCE COSTS.'),
#                                                                      (u'SharingOfRevenuesInd',
#                                                                       u'0')]))])),
#                                          (u'IRS990ScheduleM',
#                                           OrderedDict([(u'@documentId',
#                                                         u'RetDoc1042900001'),
#                                                        (u'OtherNonCashContriTableGrp',
#                                                         OrderedDict([(u'NonCashCheckboxInd',
#                                                                       u'X'),
#                                                                      (u'Desc',
#                                                                       u'OPERATING EXPENSES'),
#                                                                      (u'ContributionCnt',
#                                                                       u'1'),
#                                                                      (u'NoncashContributionsRptF990Amt',
#                                                                       u'187207'),
#                                                                      (u'MethodOfDeterminingRevenuesTxt',
#                                                                       u'ACTUAL AMOUNTS PAID')])),
#                                                        (u'Form8283ReceivedCnt',
#                                                         u'0'),
#                                                        (u'AnyPropertyThatMustBeHeldInd',
#                                                         u'0'),
#                                                        (u'ReviewProcessUnusualNCGiftsInd',
#                                                         u'0'),
#                                                        (u'ThirdPartiesUsedInd',
#                                                         u'0')])),
#                                          (u'IRS990ScheduleO',
#                                           OrderedDict([(u'@documentId',
#                                                         u'RetDoc1044400001'),
#                                                        (u'SupplementalInformationDetail',
#                                                         [OrderedDict([(u'FormAndLineReferenceDesc',
#                                                                        u'FORM 990, PART VI, SECTION A, LINE 2'),
#                                                                       (u'ExplanationTxt',
#                                                                        u'NEIL BARSKY, CHAIR AND ELCHONON STERN, SECRETARY/TREASURER AND CFO - BUSINESS RELATIONSHIP')]),
#                                                          OrderedDict([(u'FormAndLineReferenceDesc',
#                                                                        u'FORM 990, PART VI, SECTION B, LINE 11'),
#                                                                       (u'ExplanationTxt',
#                                                                        u'THE CHIEF FINANCIAL OFFICER REVIEWS THE 990 TOGETHER WITH THE CHAIR PRIOR TO FILING.')]),
#                                                          OrderedDict([(u'FormAndLineReferenceDesc',
#                                                                        u'FORM 990, PART VI, SECTION B, LINE 12C'),
#                                                                       (u'ExplanationTxt',
#                                                                        u"THE BOARD OF DIRECTORS COMPLETE AN ANNUAL DISCLOSURE STATEMENT AS REQUIRED BY THE ORGANIZATION'S CONFLICT OF INTEREST POLICY. BOARD MEMBERS ARE ALSO REQUIRED TO NOTIFY THE BOARD OF DIRECTORS WHEN ANY TRANSACTIONS ARISE THAT COULD INVOLVE AN ACTUAL OR POSSIBLE CONFLICT OF INTEREST. THE DISCLOSURE STATEMENTS AND ANY DISCOSURES MADE ARE REVIEWED BY THE TREASURER OR BOARD CHAIR FOR COMPLIANCE TO THE ORGANIZAITON'S CONFLICT OF INTEREST POLICY. IF ANY DISCLOSURES REQUIRE FURTHER INVESTIGATION, THE TREASURER OR BOARD CHAIR WORK WITH THE BOARD OF DIRECTORS TO INVESTIGATE AND RESOLVE ANY SUCH DISCLOSURES. OFFICERS, KEY EMPLOYEES AND MEMBERS OF MANAGEMENT ARE INTERVIEWED ANNUALLY FOR CONFLICT OF INTEREST DISCLOSURES. THESE RESPONSES ARE REVIEWED BY THE TREASURER OR BOARD CHAIR FOR COMPLIANCE TO THE ORGANIZATION'S CONFLICT OF INTEREST POLICY. IF ANY DISCLOSURES REQUIRE FURTHER INVESTIGATION, THE TREASURER WORKS WITH THE BOARD CHAIR TO INVESTIGATE AND RESOLVE ANY SUCH DISCLOSURES. ANY TRANSACTIONS WHICH REQUIRE REVIEW UNDER THE ORGANIZATION'S CONFLICT OF INTEREST POLICY ARE CONSIDERED BY THE BOARD OR DIRECTORS. ANY INDIVIDUAL WITH A CONFLICT, OR WHO IS A PARTY TO THE TRANSACTION BEING CONSIDERED, MAY NOT PARTICIPATE IN THE DELIBERATION OR DECISION WITH RESPECT TO THE TRANSACTION. THE BOARD OF DIRECTORS REVIEWS AND APPROVES WHETHER TO ENTER INTO THE TRANSACTION BEING CONSIDERED.")]),
#                                                          OrderedDict([(u'FormAndLineReferenceDesc',
#                                                                        u'FORM 990, PART VI, SECTION B, LINE 15'),
#                                                                       (u'ExplanationTxt',
#                                                                        u"COMPENSATION FOR OFFICERS AND THE ORGANIZATION'S KEY EMPLOYEE WAS DETERMINED BASED ON A REVIEW OF FORMS 990 OF OTHER COMPARABLE ORGANZIATIONS, AND A CAREFUL CONSIDERATION OF EACH INDIVIDUAL'S EXPERIENCE, QUALIFICATIONS, KNOWLEDGE, AND THE BEST INTERESTS OF THE ORGANIZATION. THIS PROCESS WAS UNDERTAKEN BY A GROUP OF INDEPENDENT BOARD MEMBERS. THE TERMS OF EACH CO-PRESIDENT'S EMPLOYMENT, INCLUDING COMPENSATION, ARE OUTLINED IN A WRITTEN EMPLOYMENT CONTRACT, AND WERE APPROVED UNANIMOUSLY BY ALL INDEPENDENT MEMBERS OF THE BOARD OF DIRECTORS. THE BOARD REVIEWS THE PERFORMANCE OF THE OFFICERS AND KEY EMPLOYEES AND MAY, AT THEIR DISCRETION, APPROVE CHANGES TO COMPENSATION.")]),
#                                                          OrderedDict([(u'FormAndLineReferenceDesc',
#                                                                        u'FORM 990, PART VI, SECTION C, LINE 19'),
#                                                                       (u'ExplanationTxt',
#                                                                        u'AVAILABLE UPON REQUEST.')])])]))]))]))])

# %%
#let's assign it to a variable
tmp_return = xmltodict.parse(xml_return)

# %%
#now our xml is a dict. And remember that dicts are pairs of keys and their associated values
#we can start at the top level and see what the keys are for our dict
tmp_return.keys()
# Out:
# [u'Return']

# %%
#now step deeper and deeper into each level of our dict inside of a dict inside of a dict
#by calling the keys using the dict_name['key_name'] notation 
#which looks like the filter function in pandas
#the bulk of the data we care about, which maps to all the columns in the paper 990s,
#will be in this level of the dict
tmp_return['Return']['ReturnData']['IRS990'].keys()
# Out:
# [u'@documentId',
#  u'@referenceDocumentId',
#  u'AddressChangeInd',
#  u'InitialReturnInd',
#  u'DoingBusinessAsName',
#  u'PrincipalOfficerNm',
#  u'USAddress',
#  u'GrossReceiptsAmt',
#  u'GroupReturnForAffiliatesInd',
#  u'Organization501c3Ind',
#  u'WebsiteAddressTxt',
#  u'TypeOfOrganizationCorpInd',
#  u'FormationYr',
#  u'LegalDomicileStateCd',
#  u'ActivityOrMissionDesc',
#  u'VotingMembersGoverningBodyCnt',
#  u'VotingMembersIndependentCnt',
#  u'TotalEmployeeCnt',
#  u'TotalVolunteersCnt',
#  u'TotalGrossUBIAmt',
#  u'NetUnrelatedBusTxblIncmAmt',
#  u'CYContributionsGrantsAmt',
#  u'CYProgramServiceRevenueAmt',
#  u'CYInvestmentIncomeAmt',
#  u'CYOtherRevenueAmt',
#  u'CYTotalRevenueAmt',
#  u'CYGrantsAndSimilarPaidAmt',
#  u'CYBenefitsPaidToMembersAmt',
#  u'CYSalariesCompEmpBnftPaidAmt',
#  u'CYTotalProfFndrsngExpnsAmt',
#  u'CYTotalFundraisingExpenseAmt',
#  u'CYOtherExpensesAmt',
#  u'CYTotalExpensesAmt',
#  u'CYRevenuesLessExpensesAmt',
#  u'TotalAssetsEOYAmt',
#  u'TotalLiabilitiesEOYAmt',
#  u'NetAssetsOrFundBalancesEOYAmt',
#  u'MissionDesc',
#  u'SignificantNewProgramSrvcInd',
#  u'SignificantChangeInd',
#  u'ExpenseAmt',
#  u'Desc',
#  u'TotalProgramServiceExpensesAmt',
#  u'DescribedInSection501c3Ind',
#  u'ScheduleBRequiredInd',
#  u'PoliticalCampaignActyInd',
#  u'LobbyingActivitiesInd',
#  u'SubjectToProxyTaxInd',
#  u'DonorAdvisedFundInd',
#  u'ConservationEasementsInd',
#  u'CollectionsOfArtInd',
#  u'CreditCounselingInd',
#  u'TempOrPermanentEndowmentsInd',
#  u'ReportLandBuildingEquipmentInd',
#  u'ReportInvestmentsOtherSecInd',
#  u'ReportProgramRelatedInvstInd',
#  u'ReportOtherAssetsInd',
#  u'ReportOtherLiabilitiesInd',
#  u'IncludeFIN48FootnoteInd',
#  u'IndependentAuditFinclStmtInd',
#  u'ConsolidatedAuditFinclStmtInd',
#  u'SchoolOperatingInd',
#  u'ForeignOfficeInd',
#  u'ForeignActivitiesInd',
#  u'MoreThan5000KToOrgInd',
#  u'MoreThan5000KToIndividualsInd',
#  u'ProfessionalFundraisingInd',
#  u'FundraisingActivitiesInd',
#  u'GamingActivitiesInd',
#  u'OperateHospitalInd',
#  u'GrantsToOrganizationsInd',
#  u'GrantsToIndividualsInd',
#  u'ScheduleJRequiredInd',
#  u'TaxExemptBondsInd',
#  u'EngagedInExcessBenefitTransInd',
#  u'PYExcessBenefitTransInd',
#  u'LoanOutstandingInd',
#  u'GrantToRelatedPersonInd',
#  u'BusinessRlnWithOrgMemInd',
#  u'BusinessRlnWithFamMemInd',
#  u'BusinessRlnWithOfficerEntInd',
#  u'DeductibleNonCashContriInd',
#  u'DeductibleArtContributionInd',
#  u'TerminateOperationsInd',
#  u'PartialLiquidationInd',
#  u'DisregardedEntityInd',
#  u'RelatedEntityInd',
#  u'RelatedOrganizationCtrlEntInd',
#  u'TrnsfrExmptNonChrtblRltdOrgInd',
#  u'ActivitiesConductedPrtshpInd',
#  u'ScheduleORequiredInd',
#  u'IRPDocumentCnt',
#  u'IRPDocumentW2GCnt',
#  u'EmployeeCnt',
#  u'EmploymentTaxReturnsFiledInd',
#  u'UnrelatedBusIncmOverLimitInd',
#  u'ForeignFinancialAccountInd',
#  u'ProhibitedTaxShelterTransInd',
#  u'TaxablePartyNotificationInd',
#  u'NondeductibleContributionsInd',
#  u'QuidProQuoContributionsInd',
#  u'Form8282PropertyDisposedOfInd',
#  u'RcvFndsToPayPrsnlBnftCntrctInd',
#  u'PayPremiumsPrsnlBnftCntrctInd',
#  u'IndoorTanningServicesInd',
#  u'InfoInScheduleOPartVIInd',
#  u'GoverningBodyVotingMembersCnt',
#  u'IndependentVotingMemberCnt',
#  u'FamilyOrBusinessRlnInd',
#  u'DelegationOfMgmtDutiesInd',
#  u'ChangeToOrgDocumentsInd',
#  u'MaterialDiversionOrMisuseInd',
#  u'MembersOrStockholdersInd',
#  u'ElectionOfBoardMembersInd',
#  u'DecisionsSubjectToApprovaInd',
#  u'MinutesOfGoverningBodyInd',
#  u'MinutesOfCommitteesInd',
#  u'OfficerMailingAddressInd',
#  u'LocalChaptersInd',
#  u'Form990ProvidedToGvrnBodyInd',
#  u'ConflictOfInterestPolicyInd',
#  u'AnnualDisclosureCoveredPrsnInd',
#  u'RegularMonitoringEnfrcInd',
#  u'WhistleblowerPolicyInd',
#  u'DocumentRetentionPolicyInd',
#  u'CompensationProcessCEOInd',
#  u'CompensationProcessOtherInd',
#  u'InvestmentInJointVentureInd',
#  u'WrittenPolicyOrProcedureInd',
#  u'StatesWhereCopyOfReturnIsFldCd',
#  u'UponRequestInd',
#  u'BooksInCareOfDetail',
#  u'Form990PartVIISectionAGrp',
#  u'TotalReportableCompFromOrgAmt',
#  u'TotReportableCompRltdOrgAmt',
#  u'TotalOtherCompensationAmt',
#  u'IndivRcvdGreaterThan100KCnt',
#  u'FormerOfcrEmployeesListedInd',
#  u'TotalCompGreaterThan150KInd',
#  u'CompensationFromOtherSrcsInd',
#  u'CntrctRcvdGreaterThan100KCnt',
#  u'AllOtherContributionsAmt',
#  u'NoncashContributionsAmt',
#  u'TotalContributionsAmt',
#  u'TotalRevenueGrp',
#  u'CompCurrentOfcrDirectorsGrp',
#  u'OtherSalariesAndWagesGrp',
#  u'OtherEmployeeBenefitsGrp',
#  u'PayrollTaxesGrp',
#  u'FeesForServicesLegalGrp',
#  u'FeesForServicesOtherGrp',
#  u'AdvertisingGrp',
#  u'OfficeExpensesGrp',
#  u'InformationTechnologyGrp',
#  u'OccupancyGrp',
#  u'TravelGrp',
#  u'DepreciationDepletionGrp',
#  u'InsuranceGrp',
#  u'OtherExpensesGrp',
#  u'TotalFunctionalExpensesGrp',
#  u'CashNonInterestBearingGrp',
#  u'PledgesAndGrantsReceivableGrp',
#  u'AccountsReceivableGrp',
#  u'PrepaidExpensesDefrdChargesGrp',
#  u'LandBldgEquipCostOrOtherBssAmt',
#  u'LandBldgEquipAccumDeprecAmt',
#  u'LandBldgEquipBasisNetGrp',
#  u'TotalAssetsGrp',
#  u'AccountsPayableAccrExpnssGrp',
#  u'TotalLiabilitiesGrp',
#  u'OrganizationFollowsSFAS117Ind',
#  u'UnrestrictedNetAssetsGrp',
#  u'TemporarilyRstrNetAssetsGrp',
#  u'TotalNetAssetsFundBalanceGrp',
#  u'TotLiabNetAssetsFundBalanceGrp',
#  u'ReconcilationRevenueExpnssAmt',
#  u'OtherChangesInNetAssetsAmt',
#  u'MethodOfAccountingAccrualInd',
#  u'AccountantCompileOrReviewInd',
#  u'FSAuditedInd',
#  u'FSAuditedBasisGrp',
#  u'AuditCommitteeInd',
#  u'FederalGrantAuditRequiredInd']

# %%
#choose some of the keys in this ['IRS990'] dict and see what data you can access
tmp_return['Return']['ReturnData']['IRS990']['CYTotalRevenueAmt']
# Out:
# u'5139255'

# %% [markdown]
# Now, take a few minutes and use the index (or an earlier year) to find the return of a non-profit you're interested in and explore the xml, pulling out data points of interest

# %%
#now we're going to juggle chainsaws
#let's create a function that takes a url from the column we created in the index
#it then requests the associated data and pulls out one data point
#—the Total Revenue Amount for the Calendar Year—and returns that value
def revenue(xml990_url):
    mine = requests.get(xml990_url).text[3:]
    parsed = xmltodict.parse(mine)
    calendar_revs = parsed['Return']['ReturnData']['IRS990']['CYTotalRevenueAmt']
    #we add this 1.5 second-pause in our function to avoid hammering amazon with requests
    #be very careful with this. It will make the function very slow, but it will keep you
    #from overwhelming the servers or getting your IP blacklisted
    #with a dataframe of 127 rows, this will then take more than 3 minutes to run
    #with larger dataframes, it'll take even longer
    sleep(1.5)
    return(calendar_revs)

# %%
#here again, I use the crazy .apply function on the url column and pass it to 
#the revenue function. apply runs the revenue function on all the rows at once
#again reinforcing why the sleep pause is important
#this adds a new column to our dataframe called 'revenues'
marshalls990['revenues'] = marshalls990.url.apply(lambda x: revenue(x))
# Out:
# /Users/tommeagher/.virtualenvs/pandas/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#here I convert the string of the revenue value to a float (or decimal number)
marshalls990['revenues'] = marshalls990.revenues.astype(float)
#the .max() function returns the highest number from the revenues column
marshalls990['revenues'].max()
# Out:
# /Users/tommeagher/.virtualenvs/pandas/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 242634371.0

# %%
#this filters the marshalls990 dataframe by only showing the row(s) where the revenue value is 
#the max() and then shows us just the value of the TAXPAYER_NAME field
marshalls990['TAXPAYER_NAME'][marshalls990['revenues']==marshalls990['revenues'].max()]
# Out:
# 344761    MARSHALL MEDICAL CENTER
# Name: TAXPAYER_NAME, dtype: object

# %%
#whew, that was a lot to get through. What did we miss? What else would you want to do
#with this data? Try it and then hit me up with questions
