# %% [markdown]
# We want to look through the IRS' master file of tax-exempt organizations
# and look for the zip codes with the most nonprofits
# and then look at what industries have the most nonprofits.
# This will help us quickly calculate some common descriptive stats
# as well as some easy string cleaning functions

# %%
#import our third-party library
import pandas as pd

# %%
#set this option to make your dollar amounts
#display with commas and 2 decimal places in your 
#summary dataframes
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))

# %% [markdown]
# Go to this link: https://www.irs.gov/charities-non-profits/exempt-organizations-business-master-file-extract-eo-bmf and right-click on NY
# to get the URL for the csv

# %%
#create a new dataframe by reading in the CSV at that URL
#this saves us the trouble of making the request ourself and 
#converting the response into something pandas can work with.
#This is a big help
ny = pd.read_csv('https://www.irs.gov/pub/irs-soi/eo_ny.csv')

# %%
#use the dataframe's .head() method to see the first
#few rows and columns of data
ny.head()
# Out:
#         EIN                                               NAME  \
# 0   2022084                  ST ROSALIAS ROMAN CATHOLIC CHURCH
# 1   2045409  GENERAL COUNCIL OF ASSEMBLIES OF GOD FULL GOSP...
# 2  10263908     SKOWHEGAN SCHOOL OF PAINTING AND SCULPTURE INC
# 3  10284115                                      MAIN IDEA INC
# 4  10391592                                    MAINE JAZZ CAMP
#
#                        ICO                     STREET          CITY STATE  \
# 0                      NaN               1230 65TH ST      BROOKLYN    NY
# 1                      NaN     3210 SOUTHWESTERN BLVD  ORCHARD PARK    NY
# 2                      NaN       136 WEST 22ND STREET      NEW YORK    NY
# 3  % SARAH STERN TREASURER  180 EAST PROSPECT AVE 178    MAMARONECK    NY
# 4                      NaN              PO BOX 150597      BROOKLYN    NY
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION    ...      ASSET_CD  INCOME_CD  \
# 0  11219-5614    928           3            9    ...             0          0
# 1  14127-1229   1678           3            9    ...             0          0
# 2  10011-2424      0           3            3    ...             8          6
# 3  10543-3709      0           3            3    ...             5          4
# 4  11215-0597      0           3            3    ...             2          3
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD   ASSET_AMT  INCOME_AMT  \
# 0              6                 0       12         NaN         NaN
# 1              6                 0        8         NaN         NaN
# 2              1                 0       12  18839129.0   3515868.0
# 3              1                 0       12    898463.0    478588.0
# 4              1                 0       12     21577.0     65887.0
#
#    REVENUE_AMT  NTEE_CD  SORT_NAME
# 0          NaN      NaN        NaN
# 1          NaN      NaN        NaN
# 2    2503199.0     A250        NaN
# 3     312621.0      NaN        NaN
# 4      65887.0     B99Z        NaN
#
# [5 rows x 28 columns]

# %%
#show me all my unique column names
ny.columns
# Out:
# Index([u'EIN', u'NAME', u'ICO', u'STREET', u'CITY', u'STATE', u'ZIP', u'GROUP',
#        u'SUBSECTION', u'AFFILIATION', u'CLASSIFICATION', u'RULING',
#        u'DEDUCTIBILITY', u'FOUNDATION', u'ACTIVITY', u'ORGANIZATION',
#        u'STATUS', u'TAX_PERIOD', u'ASSET_CD', u'INCOME_CD', u'FILING_REQ_CD',
#        u'PF_FILING_REQ_CD', u'ACCT_PD', u'ASSET_AMT', u'INCOME_AMT',
#        u'REVENUE_AMT', u'NTEE_CD', u'SORT_NAME'],
#       dtype='object')

# %%
#pass the filter on the ny dataframe a list of the three 
#numeric columns we want to calculate descriptive statistics for
#using the dataframe's .describe() method
ny[['ASSET_AMT','INCOME_AMT','REVENUE_AMT']].describe()
# Out:
#               ASSET_AMT        INCOME_AMT      REVENUE_AMT
# count         83,272.00         83,272.00        71,396.00
# mean       6,717,461.02      4,653,583.38     3,729,685.70
# std      136,416,583.22     98,199,804.76    71,814,748.72
# min                0.00     -1,735,647.00   -13,754,927.00
# 25%                0.00              0.00             0.00
# 50%           21,658.50         27,227.50         8,578.50
# 75%          441,835.75        283,431.50       194,880.50
# max   16,672,598,896.00 14,087,558,909.00 6,493,574,288.00

# %%
#let's calculate the maximum value in the ASSET_AMT column by using
#the column's .max() method and assign it to the ny_max variable
ny_max = ny.ASSET_AMT.max()

# %%
#similarly, we can use the column's .mean() method
ny.ASSET_AMT.mean()
# Out:
# 6717461.0158396577

# %%
#and the column's .median() method
#all of these descriptive functions take a column of numbers
#and return a single, summary number
ny.ASSET_AMT.median()
# Out:
# 21658.5

# %%
#using our ny_max variable, filter our dataframe
#to show just the nonprofit that had the max ASSET_AMT
ny[ny.ASSET_AMT==ny_max]
# Out:
#              EIN                                               NAME  \
# 31159  135598093  TRUSTEES OF COLUMBIA UNIVERSITY IN THE CITY OF...
#
#                     ICO                         STREET      CITY STATE  \
# 31159  % JULIA SHANAHAN  615 WEST 131 STREET 4TH FLOOR  NEW YORK    NY
#
#               ZIP  GROUP  SUBSECTION  AFFILIATION     ...      FILING_REQ_CD  \
# 31159  10027-7984   8057           3            6     ...                  1
#
#        PF_FILING_REQ_CD  ACCT_PD         ASSET_AMT       INCOME_AMT  \
# 31159                 0        6 16,672,598,896.00 6,284,244,530.00
#
#            REVENUE_AMT  NTEE_CD  SORT_NAME  SHORT_ZIP  SHORT_NTEE
# 31159 4,708,225,588.00     B430        NaN      10027           B
#
# [1 rows x 30 columns]

# %%
#similarly, we can create a filter that shows
#just the rows with ASSET_AMT over $10,000,000
ny[ny.ASSET_AMT>10000000]
# Out:
#               EIN                                               NAME  \
# 2        10263908     SKOWHEGAN SCHOOL OF PAINTING AND SCULPTURE INC
# 17       10553351                       DANCING TIDES FOUNDATION INC
# 90       10603628                              LEARNINGSPRING SCHOOL
# 111      10623055                            PINDAROS FOUNDATION INC
# 240      10708733                      DEMOCRACY NOW PRODUCTIONS INC
# 259      10718949                   CIVITELLA RANIERI FOUNDATION INC
# 355      10790110                           EXCELLENCE ACADEMIES INC
# 441      10880911                             THE ROSS INSTITUTE INC
# 445      10885377                                   COMIC RELIEF INC
# 554      16186903                             MERCE CUNNINGHAM TRUST
# 557      16274657                     NEW YORK UNIVERSITY VEBA TRUST
# 569      20532315            LEXINGTON HOUSING DEVELOPMENT FUND CORP
# 573      20534583                 MACAULAY HONORS COLLEGE FOUNDATION
# 614      20555237                            52 BROADWAY REALTY CORP
# 669      20590588           NATIONAL CENTER FOR CIVIC INNOVATION INC
# 677      20595263                            GOULD FAMILY FOUNDATION
# 702      20614246       SHU HAB HOUSING DEVELOPMENT FUND CORPORATION
# 762      20663534       CABRINI HOUSING DEVELOPMENT FUND CORPORATION
# 908      30213226                  INTERNATIONAL PEACE INSTITUTE INC
# 1041     30455984         NIAGARA TOURISM AND CONVENTION CORPORATION
# 1092     30495750                    CRISTO REY NEW YORK HIGH SCHOOL
# 1148     30536676                                V&L MARX FOUNDATION
# 1243     42392373               AMERICAN VACUUM SOCIETY INCORPORATED
# 1271     43032409                       BUTLER CONSERVATION FUND INC
# 1299     43254361        THEODORE CROSS FAMILY CHARITABLE FOUNDATION
# 1312     43386858  MARK D HOSTETTER AND ALEXANDER N HABIB FOUNDATION
# 1319     43414101     THE EDITH GLICK SCHOOLMAN CHILDRENS FOUNDATION
# 1326     43493352                          CLOUD MOUNTAIN FOUNDATION
# 1328     43519203                                        NEW LEADERS
# 1395     43635313                                 CIVIC BUILDERS INC
# ...           ...                                                ...
# 105911  911792864               ALZHEIMERS FOUNDATION OF AMERICA INC
# 105978  911884698   NDC HOUSING AND ECONOMIC DEVELOPMENT CORPORATION
# 105991  911898350                        ROY LICHTENSTEIN FOUNDATION
# 106024  911917512           QUEENS COLLEGE SPECIAL PROJECTS FUND INC
# 106032  911918247                   SERVICES FOR THE UNDERSERVED INC
# 106037  911922828                                    H E L P USA INC
# 106039  911922911                      HOUSING VISIONS UNLIMITED INC
# 106134  912071511                   SERVICES FOR THE UNDERSERVED INC
# 106187  912135195                  BON SECOURS CHARITY HEALTH SYSTEM
# 106202  912154267             MEMORIAL SLOAN-KETTERING CANCER CENTER
# 106284  931234568                      T & J MEYER FAMILY FOUNDATION
# 106292  942443282                              GLOBAL HUNGER PROJECT
# 106305  942843176                 INTERNATIONAL STUDENT EXCHANGE INC
# 106355  943235545                                 SAPLING FOUNDATION
# 106360  943273384                     CARMEL MOUNTAIN APARTMENTS INC
# 106385  943398566       MAJOR LEAGUE BASEBALL URBAN YOUTH FOUNDATION
# 106439  943462623  BUFFALO STATE COLLEGE FOUNDATION HOUSING CORPO...
# 106474  946109313                                  WEEDEN FOUNDATION
# 106475  946182697                                  MULAGO FOUNDATION
# 106513  953992053                                    NOUR FOUNDATION
# 106516  954081892                              THE DILLER FOUNDATION
# 106527  954335088                       LYMPHOMA RESEARCH FOUNDATION
# 106536  954617492                           MOZILO FAMILY FOUNDATION
# 106553  954870786         KENNETT EXC ASSOCIATES INC A DELAWARE CORP
# 106562  980013401                     ST STEPHENS SCHOOL CORPORATION
# 106567  980115409                                      PRO MUJER INC
# 106577  980483202  FUDAN UNIVERSITY EDUCATION DEVELOPMENT FOUNDATION
# 106579  980519204  THE ALTERNATIVE INVESTMENT MANAGEMENT ASSOCIAT...
# 106591  986000319                    FOUNDATION FOR ARTS INITIATIVES
# 106592  986001286                         FONDATION FRANCQUI BELGIUM
#
#                                         ICO  \
# 2                                       NaN
# 17                           % JEFF WILKINS
# 90                         % MARILYN SIMONS
# 111              % MARKS PANETH & SHRON LLP
# 240                                     NaN
# 259                        % THE FOUNDATION
# 355                          % CAROLYN HACK
# 441                          % DUANE RITTER
# 445                       % RICHARD L SCOTT
# 554                 % CUNNINGHAM MERCE TTEE
# 557                   % NEW YORK UNIVERSITY
# 569                           % MET COUNCIL
# 573                        % CAROLYN GEISEL
# 614         % UNITED FEDERATION OF TEACHERS
# 669     % FUND FOR THE CITY OF NEW YORK INC
# 677                  % COUDERT BROTHERS LLP
# 702                                     NaN
# 762                                     NaN
# 908                                     NaN
# 1041                                    NaN
# 1092                   % WILLIAM P FORD III
# 1148                   % JENNIFER GRUENBERG
# 1243                                    NaN
# 1271                                    NaN
# 1299         % SUSAN L REPETTI-NUTTER ET AL
# 1312                     % MARK D HOSTETTER
# 1319               % PKF OCONNOR DAVIES LLP
# 1326    % WAGNER FERBER FINE & ACKERMAN PLL
# 1328                                    NaN
# 1395                       % J DAVID SWEENY
# ...                                     ...
# 105911             % CHARLES J FUSCHILLO JR
# 105978                                  NaN
# 105991               % DOROTHY LICHTENSTEIN
# 106024                   % JEANNE DEMASTERS
# 106032                                  NaN
# 106037                                  NaN
# 106039                                  NaN
# 106134                   % PERRY PERLMUTTER
# 106187                      % PETER KENNIFF
# 106202                 % MARK K SVENNINGSON
# 106284                   % CITRIN COOPERMAN
# 106292                                  NaN
# 106305                                  NaN
# 106355                    % TED CONFERENCES
# 106360                        % MARIA BRITO
# 106385                     % ROBERT J CLARK
# 106439                  % STANLEY KARDONSKY
# 106474                        % ALAN WEEDEN
# 106475                        % JOEL SAMMET
# 106513                                  NaN
# 106516        % SARAH KNUTSON ARROW INVSTMN
# 106527                                  NaN
# 106536                 % THE AYCO CO LP-NTG
# 106553      % URDANG CAPITAL MANAGEMENT INC
# 106562                                  NaN
# 106567                       % NORMA SEGURA
# 106577                                  NaN
# 106579                                  NaN
# 106591                                  NaN
# 106592                      % LUTZ AND CARR
#
#                                      STREET              CITY STATE  \
# 2                      136 WEST 22ND STREET          NEW YORK    NY
# 17                        1475 FRANKLIN AVE       GARDEN CITY    NY
# 90                            247 E 20TH ST          NEW YORK    NY
# 111                                 685 3RD          NEW YORK    NY
# 240             207 WEST 25TH ST 11TH FLOOR          NEW YORK    NY
# 259                            28 HUBERT ST          NEW YORK    NY
# 355                  826 BROADWAY 9TH FLOOR          NEW YORK    NY
# 441                        18 GOODFRIEND DR      EAST HAMPTON    NY
# 445                   488 MADISON AVE FL 10          NEW YORK    NY
# 554                    130 W 56TH ST RM 708          NEW YORK    NY
# 557             105 EAST 17TH STREET 2ND FL          NEW YORK    NY
# 569                  120 BROADWAY 7TH FLOOR          NEW YORK    NY
# 573                            35 W 67TH ST          NEW YORK    NY
# 614                             52 BROADWAY          NEW YORK    NY
# 669                        121 SIXTH AVENUE          NEW YORK    NY
# 677                 229 CHRYSTIE ST APT 816          NEW YORK    NY
# 702                           8714 116TH ST     RICHMOND HILL    NY
# 762                    220 EAST 19TH STREET          NEW YORK    NY
# 908                777 UNITED NATIONS PLAZA          NEW YORK    NY
# 1041                        10 RAINBOW BLVD     NIAGARA FALLS    NY
# 1092                      112 EAST 106TH ST          NEW YORK    NY
# 1148                        14 BROOKLINE RD         SCARSDALE    NY
# 1243                125 MAIDEN LANE 15TH FL          NEW YORK    NY
# 1271          60 CUTTER MILL ROAD SUITE 212        GREAT NECK    NY
# 1299                       100 MERRICK ROAD  ROCKVILLE CENTRE    NY
# 1312                          306 W 98TH ST          NEW YORK    NY
# 1319                  201 E 79TH ST APT 12D          NEW YORK    NY
# 1326                 237 W 35TH ST STE 1001          NEW YORK    NY
# 1328                     30 W 26TH ST FL 10          NEW YORK    NY
# 1395               304 HUDSON STREET 3RD FL          NEW YORK    NY
# ...                                     ...               ...   ...
# 105911             322 EIGHTH AVENUE 7TH FL          NEW YORK    NY
# 105978            1 BATTERY PARK PLZ FL 710          NEW YORK    NY
# 105991                    739 WASHINGTON ST          NEW YORK    NY
# 106024   65-30 KISSENA BOULEVARD KIELY 1305          FLUSHING    NY
# 106032             305 SEVENTH AVE 10TH FLR          NEW YORK    NY
# 106037                        115 E 13TH ST          NEW YORK    NY
# 106039             1201 E FAYETTE ST STE 26          SYRACUSE    NY
# 106134        305 SEVENTH AVENUE 10TH FLOOR          NEW YORK    NY
# 106187                    255 LAFAYETTE AVE           SUFFERN    NY
# 106202                        1275 YORK AVE          NEW YORK    NY
# 106284     C/O CITRIN COOPERMAN 529 5TH AVE          NEW YORK    NY
# 106292                      59 UNION SQUARE          NEW YORK    NY
# 106305                          36 PARK AVE         BAY SHORE    NY
# 106355                330 HUDSON ST 11TH FL          NEW YORK    NY
# 106360                  40 EAST 52ND STREET          NEW YORK    NY
# 106385                      245 PARK AVENUE          NEW YORK    NY
# 106439  1300 ELMWOOD AVENUE CLE HALL NO 417           BUFFALO    NY
# 106474               35 ADAMS ST LOWER UNIT     BEDFORD HILLS    NY
# 106475                 15 MAIDEN LN STE 500          NEW YORK    NY
# 106513                       322 W 108TH ST          NEW YORK    NY
# 106516                 555 W 18TH ST 5TH FL          NEW YORK    NY
# 106527                 115 BROADWAY RM 1301          NEW YORK    NY
# 106536                         PO BOX 15014            ALBANY    NY
# 106553  1251 AVENUE OF THE AMERICAS 35TH FL          NEW YORK    NY
# 106562                   15 GRAMERCY PARK S          NEW YORK    NY
# 106567                253 W 35TH ST 11TH FL          NEW YORK    NY
# 106577                  4126 27TH ST APT 6H      LONG IS CITY    NY
# 106579  167 FLEET STREET LONDON EC4A 2EA UK          NEW YORK    NY
# 106591                     375 GREENWICH ST          NEW YORK    NY
# 106592                   551 5TH AVE RM 400          NEW YORK    NY
#
#                ZIP  GROUP  SUBSECTION  AFFILIATION            ...             \
# 2       10011-2424      0           3            3            ...
# 17      11530-1662      0           3            3            ...
# 90      10003-1801      0           3            3            ...
# 111     10017-4024      0           3            3            ...
# 240     10001-7161      0           3            3            ...
# 259     10013-2041      0           3            3            ...
# 355     10003-4826      0           3            3            ...
# 441     11937-2584      0           3            3            ...
# 445     10022-5723      0           3            3            ...
# 554     10019-3962      0           3            3            ...
# 557     10003-2170      0           9            3            ...
# 569     10271-0021      0           3            3            ...
# 573     10023-6203      0           3            3            ...
# 614     10004-1603      0           2            3            ...
# 669     10013-1510      0           3            3            ...
# 677     10002-1174      0           3            3            ...
# 702     11418-2426      0           3            3            ...
# 762     10003-2600    928           3            9            ...
# 908     10017-3521      0           3            3            ...
# 1041    14303-1132      0           6            3            ...
# 1092    10029-4651      0           3            3            ...
# 1148    10583-6004      0           3            3            ...
# 1243    10038-4912      0           3            3            ...
# 1271    11021-3131      0           3            3            ...
# 1299    11570-4800      0           3            3            ...
# 1312    10025-5559      0           3            3            ...
# 1319    10075-0839      0           3            3            ...
# 1326    10001-1950      0           3            3            ...
# 1328    10010-2159      0           3            3            ...
# 1395    10013-1015      0           3            3            ...
# ...            ...    ...         ...          ...            ...
# 105911  10001-8001      0           3            3            ...
# 105978  10004-1704   9219           3            9            ...
# 105991  10014-2042      0           3            3            ...
# 106024  11367-1597      0           3            3            ...
# 106032  10001-6146   5300           3            6            ...
# 106037  10003-5305   8201           3            9            ...
# 106039  13210-1989   8105           3            9            ...
# 106134  10001-6146   5300           3            9            ...
# 106187  10901-4812   5747           3            6            ...
# 106202  10065-6007   3475           3            9            ...
# 106284  10017-0000      0           3            3            ...
# 106292  10003-0000      0           3            3            ...
# 106305  11706-7309      0           3            3            ...
# 106355  10013-1046      0           3            3            ...
# 106360  10022-5911      0          25            3            ...
# 106385  10167-0002      0           3            3            ...
# 106439  14222-0000      0           3            3            ...
# 106474  10507-1819      0           3            3            ...
# 106475  10038-5117      0           3            3            ...
# 106513  10025-2756      0           3            3            ...
# 106516  10011-2822      0           3            3            ...
# 106527  10006-1623      0           3            3            ...
# 106536  12212-5014      0           3            3            ...
# 106553  10020-1104      0          25            3            ...
# 106562  10003-1705      0           3            3            ...
# 106567  10001-1907      0           3            3            ...
# 106577  11101-3840      0           3            3            ...
# 106579  10169-0000      0           6            3            ...
# 106591  10013-2376      0           3            3            ...
# 106592  10176-0423      0           3            3            ...
#
#         ASSET_CD  INCOME_CD  FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  \
# 2              8          6              1                 0       12
# 17             8          6              0                 1       12
# 90             8          7              1                 0        6
# 111            8          6              0                 1       12
# 240            8          7              1                 0       12
# 259            8          6              0                 1       12
# 355            9          5              1                 0        6
# 441            9          8              1                 0        6
# 445            8          8              1                 0       12
# 554            8          7              0                 1       12
# 557            9          8              1                 0        8
# 569            8          5              1                 0       12
# 573            8          6              1                 0        6
# 614            8          8              1                 0        7
# 669            8          7              1                 0        9
# 677            8          7              0                 1       12
# 702            8          6              1                 0       12
# 762            8          5              1                 0       12
# 908            8          8              1                 0       12
# 1041           8          6              1                 0       12
# 1092           8          7              1                 0        6
# 1148           9          8              0                 1       12
# 1243           8          7              1                 0       12
# 1271           9          6              0                 1       12
# 1299           8          6              0                 1       12
# 1312           8          1              0                 1       12
# 1319           8          7              0                 1       12
# 1326           8          8              0                 1       12
# 1328           8          8              1                 0        6
# 1395           9          7              1                 0       12
# ...          ...        ...            ...               ...      ...
# 105911         8          7              1                 0       12
# 105978         9          9              3                 0       12
# 105991         9          6              0                 1       12
# 106024         9          7              1                 0        6
# 106032         8          8              1                 0        6
# 106037         9          9              3                 0        6
# 106039         8          8              3                 0       12
# 106134         9          9              3                 0        6
# 106187         8          0              2                 0       12
# 106202         9          9              3                 0       12
# 106284         8          7              0                 1       12
# 106292         8          8              1                 0       12
# 106305         8          8              1                 0        8
# 106355         9          9              0                 1       12
# 106360         9          7              1                 0       12
# 106385         8          7              1                 0       12
# 106439         8          7              1                 0        6
# 106474         8          8              0                 1       12
# 106475         9          9              0                 1       12
# 106513         8          7              1                 0       12
# 106516         8          8              0                 1       12
# 106527         8          7              1                 0        6
# 106536         8          8              0                 1       12
# 106553         9          7              1                 0        6
# 106562         8          8              1                 0        8
# 106567         9          8              1                 0       12
# 106577         8          5              1                 0       12
# 106579         8          8              1                 0       12
# 106591         8          6              0                 1        8
# 106592         8          6              0                 1       12
#
#               ASSET_AMT       INCOME_AMT      REVENUE_AMT  NTEE_CD  \
# 2         18,839,129.00     3,515,868.00     2,503,199.00     A250
# 17        20,918,833.00     2,490,358.00              nan      T22
# 90        45,952,763.00     7,202,443.00     6,463,225.00      B28
# 111       38,882,811.00     3,080,407.00              nan      T22
# 240       20,406,857.00     9,155,773.00     8,158,144.00      A30
# 259       24,031,526.00     4,814,547.00              nan      NaN
# 355       51,159,617.00       603,539.00       603,539.00     B192
# 441      102,144,099.00    38,476,680.00    37,932,416.00      B20
# 445       12,757,292.00    38,027,287.00    38,027,287.00      T12
# 554       10,602,952.00     5,206,721.00              nan      T23
# 557       84,770,687.00    13,127,647.00    13,127,647.00      Y43
# 569       10,974,511.00       573,452.00       573,452.00      L22
# 573       10,441,938.00     3,053,958.00     2,863,356.00      B80
# 614       38,556,178.00    13,240,939.00    13,240,939.00      Z99
# 669       27,879,046.00     6,625,243.00     6,625,243.00      S43
# 677       21,079,534.00     6,507,527.00              nan      T22
# 702       16,319,483.00     2,195,950.00     2,195,950.00      L20
# 762       13,243,000.00       692,157.00       692,157.00      NaN
# 908       15,659,798.00    11,677,388.00    10,334,339.00     Q400
# 1041      10,006,188.00     4,299,750.00     4,299,750.00      S41
# 1092      14,051,374.00     5,622,757.00     5,451,313.00      B25
# 1148      73,772,084.00    11,368,081.00              nan      T20
# 1243      13,239,281.00     5,796,306.00     3,392,360.00     U99Z
# 1271     134,403,458.00     1,710,959.00              nan      C19
# 1299      17,875,049.00     2,957,681.00              nan     T20J
# 1312      21,901,125.00         3,218.00              nan     T22Z
# 1319      19,923,453.00     7,218,012.00              nan      T20
# 1326      30,344,199.00    12,293,993.00              nan      T22
# 1328      29,247,493.00    29,409,855.00    29,409,855.00      B50
# 1395      57,276,917.00     9,224,425.00     9,099,362.00      L99
# ...                 ...              ...              ...      ...
# 105911    12,842,514.00     9,205,772.00     9,145,745.00     G83A
# 105978 1,145,379,211.00    97,968,464.00    75,150,583.00     L200
# 105991    65,966,512.00     3,190,799.00              nan     T99Z
# 106024    61,237,645.00     6,524,372.00     6,524,372.00     T50Z
# 106032    42,575,480.00    13,819,294.00    13,528,077.00      NaN
# 106037   173,131,657.00    99,048,382.00    97,998,555.00     L410
# 106039    34,340,179.00    36,524,400.00    36,420,963.00      NaN
# 106134    65,044,864.00   119,007,411.00   119,007,411.00      NaN
# 106187    23,776,701.00             0.00             0.00      E21
# 106202 9,586,730,000.00 4,317,513,766.00 3,867,024,714.00     E240
# 106284    24,881,985.00     5,376,815.00              nan     T90Z
# 106292    13,731,782.00    16,678,119.00    16,146,404.00     Q300
# 106305    14,400,733.00    11,476,478.00    11,476,478.00     Q220
# 106355    53,254,015.00    74,724,713.00              nan      T23
# 106360    94,159,149.00     6,368,569.00     6,368,569.00      NaN
# 106385    14,345,889.00     7,672,833.00     7,672,833.00      N63
# 106439    43,673,908.00     5,143,744.00     5,143,744.00     B113
# 106474    31,271,135.00    20,882,706.00              nan      NaN
# 106475   324,403,880.00   321,482,946.00              nan      T20
# 106513    10,462,640.00     9,799,418.00     1,506,519.00      P20
# 106516    12,176,140.00    17,634,531.00              nan      NaN
# 106527    10,579,908.00     9,729,452.00     9,216,291.00      G80
# 106536    14,839,792.00    33,073,973.00              nan     T99Z
# 106553    70,890,295.00     5,214,284.00     3,401,801.00      S47
# 106562    11,997,574.00    16,121,624.00     9,946,557.00      NaN
# 106567   140,454,089.00    48,736,087.00    48,263,169.00     Q300
# 106577    24,182,982.00       892,246.00       892,246.00      B82
# 106579    10,303,698.00    10,082,985.00    10,082,985.00      S41
# 106591    23,712,986.00     3,871,567.00              nan      T20
# 106592    41,988,121.00     1,968,125.00              nan      NaN
#
#                        SORT_NAME
# 2                            NaN
# 17          ARNELL NATHAN E TTEE
# 90                           NaN
# 111                          NaN
# 240                          NaN
# 259                          NaN
# 355                          NaN
# 441                          NaN
# 445                          NaN
# 554        CUNNINGHAM MERCE TTEE
# 557                          NaN
# 569                          NaN
# 573                          NaN
# 614                          NaN
# 669                          NaN
# 677     MATTHEWS EDWIN S JR TTEE
# 702                          NaN
# 762                          NaN
# 908                          NaN
# 1041                         NaN
# 1092                         NaN
# 1148                         NaN
# 1243                         NaN
# 1271                         NaN
# 1299                         NaN
# 1312                         NaN
# 1319      BREZNAY DEBORAH B TTEE
# 1326                         NaN
# 1328                         NaN
# 1395                         NaN
# ...                          ...
# 105911                       NaN
# 105978              GROUP RETURN
# 105991                       NaN
# 106024                       NaN
# 106032                       NaN
# 106037              GROUP RETURN
# 106039              GROUP RETURN
# 106134              GROUP RETURN
# 106187                       NaN
# 106202              GROUP RETURN
# 106284                       NaN
# 106292                       NaN
# 106305                       NaN
# 106355                       NaN
# 106360                       NaN
# 106385                       NaN
# 106439                       NaN
# 106474                       NaN
# 106475                       NaN
# 106513                       NaN
# 106516                       NaN
# 106527                       NaN
# 106536                       NaN
# 106553                       NaN
# 106562                       NaN
# 106567                       NaN
# 106577                       NaN
# 106579                       NaN
# 106591                       NaN
# 106592                       NaN
#
# [4346 rows x 28 columns]

# %%
#so getting back to one of our first questions
#which zip has the most nonprofits?
#the problem here is that the zip with the +4 number
#is too small a geography, too specific.
ny.ZIP.value_counts()
# Out:
# 14203-2309    325
# 14450-0444    263
# 10017-0000    203
# 11210-3714    166
# 13815-0000    141
# 10022-0000    141
# 10018-0000    139
# 10019-0000    128
# 11120-0001    123
# 10016-0000    107
# 10005-4414    100
# 14850-0000     96
# 12212-5014     89
# 10036-0000     88
# 10163-5005     84
# 10001-7604     78
# 10010-4102     77
# 10027-0000     75
# 10001-0000     74
# 13815-1646     71
# 10008-1297     70
# 10005-0000     69
# 10007-2233     68
# 10005-4401     67
# 14221-7748     67
# 11229-4111     66
# 10111-0100     64
# 12866-0860     62
# 10017-4201     59
# 10023-0000     59
#              ...
# 11210-1364      1
# 14051-1753      1
# 11375-5734      1
# 11213-4037      1
# 11211-0521      1
# 11213-4038      1
# 10977-3854      1
# 10977-3856      1
# 10977-3857      1
# 14209-0852      1
# 12309-6413      1
# 11705-1500      1
# 14214-1328      1
# 11710-2455      1
# 11201-1595      1
# 11754-0201      1
# 13460-0818      1
# 10960-3122      1
# 10024-5408      1
# 11214-3725      1
# 10011-5434      1
# 11434-7042      1
# 10025-2206      1
# 10036-3464      1
# 10977-2103      1
# 11362-1934      1
# 14850-9605      1
# 10023-5923      1
# 13748-0100      1
# 10033-5012      1
# Name: ZIP, Length: 74086, dtype: int64

# %%
#let's "apply" a function to every row in the ZIP column of the ny dataframe
#we can use lambda to make that function for the variable x 
#(each cell in that column) on the fly
#here we split the full zip+4 string on the dash ('-') and 
#choose the first item in the list that's returned: the 5-digit zip
ny['SHORT_ZIP'] = ny.ZIP.apply(lambda x: x.split('-')[0])

# %% [markdown]
# Explaining apply: https://stackoverflow.com/questions/19798153/difference-between-map-applymap-and-apply-methods-in-pandas
# "Summing up, apply works on a row / column basis of a DataFrame, applymap works element-wise on a DataFrame, and map works element-wise on a Series."

# %%
#look at the first five rows of our new, SHORT_ZIP column
#this looks like what we want
ny.SHORT_ZIP.head()
# Out:
# 0    11219
# 1    14127
# 2    10011
# 3    10543
# 4    11215
# Name: SHORT_ZIP, dtype: object

# %%
#now try value counts on the new column
#that's a very different place than the full zip+4 value_counts we did before
ny.SHORT_ZIP.value_counts()
# Out:
# 10022    1273
# 11219    1229
# 10017    1109
# 10001    1018
# 10016     977
# 10018     955
# 11211     952
# 10036     859
# 10019     839
# 10952     763
# 10023     722
# 10003     702
# 11204     677
# 11210     633
# 10025     629
# 11201     605
# 10011     603
# 11230     583
# 14203     558
# 10024     555
# 10010     529
# 10004     525
# 10027     501
# 10977     500
# 14850     500
# 10013     492
# 10021     485
# 10005     474
# 14450     442
# 10128     429
#          ...
# 12195       1
# 10060       1
# 13758       1
# 10286       1
# 11453       1
# 14893       1
# 13611       1
# 12240       1
# 12769       1
# 12768       1
# 13450       1
# 12465       1
# 11256       1
# 14261       1
# 14884       1
# 12781       1
# 12785       1
# 13847       1
# 12784       1
# 14827       1
# 12416       1
# 14824       1
# 14477       1
# 14475       1
# 12511       1
# 13129       1
# 12411       1
# 13457       1
# 12417       1
# 11915       1
# Name: SHORT_ZIP, Length: 1970, dtype: int64

# %% [markdown]
# Remember to consult our data dictionary: https://www.irs.gov/pub/irs-soi/eo_info.pdf

# %%
#now we want to know which industry has the most nonprofits.
#After reading our data dictionary carefully, we see that it's
#the NTEE_CD column that has the codes we want
#but, like our zip codes, this is a little too specific.
ny.NTEE_CD.value_counts()
# Out:
# X20     2702
# T20     2514
# X30     2435
# X21     2129
# T22     2125
# P20     1628
# B82     1318
# T30      994
# O50      969
# D20      837
# S41      822
# A20      744
# M24      740
# B90      734
# Q33      717
# B99      658
# A23      646
# N60      631
# A80      629
# A65      587
# N50      573
# S20      565
# X20Z     541
# J40      540
# B94      532
# W30      494
# B11      489
# X99      469
# P99      461
# A68      427
#         ...
# W60I       1
# E50J       1
# G038       1
# T015       1
# K033       1
# K032       1
# G300       1
# P70C       1
# E602       1
# N00Z       1
# B4XZ       1
# A55Z       1
# B057       1
# C030       1
# U31C       1
# Y220       1
# A41Z       1
# E87Z       1
# A613       1
# H70Z       1
# M054       1
# G320       1
# A77J       1
# P377       1
# K11        1
# P114       1
# F22M       1
# F22I       1
# E50L       1
# A6EI       1
# Name: NTEE_CD, Length: 2314, dtype: int64

# %%
#the .describe() method in this string column
#tells us how many have values and how many repeat
#and the most popular one
ny.NTEE_CD.describe()
# Out:
# count     69572
# unique     2314
# top         X20
# freq       2702
# Name: NTEE_CD, dtype: object

# %%
#but looking at the .info() method of the whole dataframe
#we see that there are many rows of the NTEE_CD column
#that are empty
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106607 entries, 0 to 106606
# Data columns (total 29 columns):
# EIN                 106607 non-null int64
# NAME                106607 non-null object
# ICO                 68630 non-null object
# STREET              106607 non-null object
# CITY                106607 non-null object
# STATE               106607 non-null object
# ZIP                 106607 non-null object
# GROUP               106607 non-null int64
# SUBSECTION          106607 non-null int64
# AFFILIATION         106607 non-null int64
# CLASSIFICATION      106607 non-null int64
# RULING              106607 non-null int64
# DEDUCTIBILITY       106607 non-null int64
# FOUNDATION          106607 non-null int64
# ACTIVITY            106607 non-null int64
# ORGANIZATION        106607 non-null int64
# STATUS              106607 non-null int64
# TAX_PERIOD          83994 non-null float64
# ASSET_CD            106607 non-null int64
# INCOME_CD           106607 non-null int64
# FILING_REQ_CD       106607 non-null int64
# PF_FILING_REQ_CD    106607 non-null int64
# ACCT_PD             106607 non-null int64
# ASSET_AMT           83272 non-null float64
# INCOME_AMT          83272 non-null float64
# REVENUE_AMT         71396 non-null float64
# NTEE_CD             69572 non-null object
# SORT_NAME           21673 non-null object
# SHORT_ZIP           106607 non-null object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 23.6+ MB

# %%
#to allow us to clean up the strings in NTEE_CD column
#we need to fill in any blanks (or "na's") with 0s
#because you can't slice a string ("x[0]", for instance)
#that doesn't exist
ny.NTEE_CD.fillna('0', inplace=True)

# %%
#like our zips above, let's apply a new function to each cell
#in each row of the NTEE_CD column and assign the result to
#a new column in our dataframe.
#we'll take each string and just take the 0th character (first in Python)
#in this instance, that's the one-letter code for the industry groups
#according to the IRS's classification
ny['SHORT_NTEE'] = ny.NTEE_CD.apply(lambda x: x[0])

# %%
#see the first few rows of the shortened column
ny.SHORT_NTEE.head()
# Out:
# 0    0
# 1    0
# 2    A
# 3    0
# 4    B
# Name: SHORT_NTEE, dtype: object

# %%
#run value counts. At the top are the empty rows that we filled with "0"
#then X for religious organizations and T for philanthropies
ny.SHORT_NTEE.value_counts()
# Out:
# 0    37036
# X    10723
# T     8780
# B     8051
# A     7909
# P     6266
# N     4194
# S     3467
# E     2571
# Q     2129
# L     2002
# O     1746
# M     1419
# D     1402
# C     1254
# W     1137
# J      993
# G      892
# Y      814
# F      777
# I      630
# Z      551
# K      536
# R      494
# H      464
# U      232
# V      138
# Name: SHORT_NTEE, dtype: int64

# %%
#what would you want to know next?
